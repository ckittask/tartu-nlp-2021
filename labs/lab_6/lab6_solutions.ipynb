# %% [markdown]
# # Lab 6. Sequence Tagging with LSTM
#
# Last time we looked at the text classification with the [Convolutional Neural Networks](https://en.wikipedia.org/wiki/Convolutional_neural_network). While this concept worked quite well for this task, it would be very difficult to apply it to the sequence tagging task.
#
# First, let's find out what **sequence tagging** or **sequence labeling** stands for. Sequence tagging is a task of assigning some tag, or label, to each element in the sequence. It can be a name entitiy tag or a pos-tag. You can already see that CNNs are not really applicable for this task since they transform the whole input into some feature vector.
#
# To assign a label for each element in a sequence, we need to apply some transformation for each element as well. However, the _context_ can be very important for choosing the correct tag. For example, a noun is usually preceded by an article. We can achieve this with [recurrent neural networks](https://en.wikipedia.org/wiki/Recurrent_neural_network).
#
# To have a more illustative example, let's look at the picture below:
#
# ![image.png](https://github.com/501Good/tartu-nlp-2020/blob/master/labs/lab5/img1.png?raw=1)
#
# Here, a square with the diagonal stripes is an **RNN unit**.

# %% [markdown]
# To better understand what these outputs mean and how we can use them, let's look inside one of the RNN units, or **RNN cells**.
#
#
# <img src="https://miro.medium.com/max/1036/1*68EDFvjbY2EJG9IkKmWkZw.png" >
#
# This simple cell consists of only one TanH activation function (it can be replaced with ReLU). As an input, it takes the **hidden state** from the previous cell and the input itself which can be a word embedding, for example. In this case, the output hidden state is the same as the output of the cell. Passing this hidden state as an input to the next cell will transfer some information from the context.
#
# Now, the cell above is very simple. There are more efficient variations like [LSTM](https://en.wikipedia.org/wiki/Long_short-term_memory) or [GRU](https://en.wikipedia.org/wiki/Gated_recurrent_unit).
#
# Let's look inside an LSTM cell.
#
# <a title="Guillaume Chevalier / CC BY (https://creativecommons.org/licenses/by/4.0)" href="https://commons.wikimedia.org/wiki/File:The_LSTM_cell.png"><img width="512" alt="The LSTM cell" src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/The_LSTM_cell.png/512px-The_LSTM_cell.png"></a>
#
# We can see, that it has more inputs and outputs, as well as more layers inside the cell, but the main concept stays the same. This time $h_t$ is a hidden state at the timestamp $t$, and $c_t$ is a **cell state** at the timestep $t$.
#
# As we are going to impliment an LSTM model in this Lab, we need to understand how to route the inputs and outputs correctly. The inside magic of the network will be done for us by PyTorch. Our job is just to plug in the wires into the correct slots.
#
# You can also read more about LSTMs [in this blog](http://colah.github.io/posts/2015-08-Understanding-LSTMs/).

# %% [markdown]
# ## POS tagging for your language
#
# In this Lab, you are going to create a pos tagger for the language of your choice. I encourage you to try to use your native language.
#
# First, let's import everything that we might need.

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.nn.utils.rnn import pad_sequence, pack_sequence, pack_padded_sequence, pad_packed_sequence, PackedSequence
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import random
import numpy as np
from time import time
from datetime import datetime

from pathlib import Path
from collections import Counter

from typing import List, Dict

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# We are going to need the pretrained word vectors. For this network, we can use the [Fasttext](https://fasttext.cc/docs/en/crawl-vectors.html) vectors since they have a lot of languages available. For this lab I am using word vectors for English. To download the vectors for your language, you need to replace the link with your **text vectors** from the table at the link above.
#
# For example, that link for Estonian word vectors will be: `https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.et.300.vec.gz`
#
# Run the two cells below to download and unpack the vectors.

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.vec.gz
# Out:
# --2021-04-06 13:33:48--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.vec.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1325960915 (1.2G) [binary/octet-stream]
# Saving to: ‘cc.en.300.vec.gz’
#
# cc.en.300.vec.gz    100%[===================>]   1.23G  23.9MB/s    in 54s
#
# 2021-04-06 13:34:42 (23.6 MB/s) - ‘cc.en.300.vec.gz’ saved [1325960915/1325960915]

# %%
# !gunzip cc.en.300.vec.gz
# !mkdir vector_cache/
# !mv cc.en.300.vec vector_cache/

# %% [markdown]
# Next, we need the data to train on. For this task, we are going to use [Universal Dependencies](https://universaldependencies.org/) data. It has labelled corpora for morphological tagging and syntax parsing for over than 70 languages. You need to choose your language from the official UD page, choose the treebank that you like and follow the GitHub link to it. Then, from GitHub, copy the link from the green "Clone or download" button and replace it in the cell below.
#
# Also, replace the name of your treebank in the `!mv` command.
#
# For example, if I choose the EDT treebank for Estonian from [here](https://universaldependencies.org/#estonian-treebanks), the GitHub link is going to be `https://github.com/UniversalDependencies/UD_Estonian-EDT.git` and the name of the treebank is `UD_Estonian-EDT`, which is the name of the repository.

# %%
# !git clone https://github.com/UniversalDependencies/UD_English-GUM.git
# Out:
# Cloning into 'UD_English-GUM'...
# remote: Enumerating objects: 1270, done.
# remote: Counting objects: 100% (1270/1270), done.
# remote: Compressing objects: 100% (499/499), done.
# remote: Total 2259 (delta 1114), reused 920 (delta 771), pack-reused 989
# Receiving objects: 100% (2259/2259), 14.99 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (2004/2004), done.

# %%
# !mkdir data/
# !mv UD_English-GUM data/

# %% [markdown]
# This part is moslty the same as in the previous lab.
#
# **Don't forget to change the `VEC_PATH` and `DATA_PATH` variables to match your data!**

# %%
PAD = '<PAD>'
PAD_ID = 0
UNK = '<UNK>'
UNK_ID = 1
VOCAB_PREFIX = [PAD, UNK]

VEC_PATH = Path('vector_cache') / 'cc.en.300.vec'
DATA_PATH = Path('data') / 'UD_English-GUM'
MAX_VOCAB = 25000

batch_size = 64
validation_split = .3
shuffle_dataset = True
random_seed = 42

# %% [markdown]
# ## Building the Vocabs

# %%
class BaseVocab:
    def __init__(self, data, idx=0, lower=False):
        self.data = data
        self.lower = lower
        self.idx = idx
        self.build_vocab()
        
    def normalize_unit(self, unit):
        if self.lower:
            return unit.lower()
        else:
            return unit
        
    def unit2id(self, unit):
        unit = self.normalize_unit(unit)
        if unit in self._unit2id:
            return self._unit2id[unit]
        else:
            return self._unit2id[UNK]
    
    def id2unit(self, id):
        return self._id2unit[id]
    
    def map(self, units):
        return [self.unit2id(unit) for unit in units]

    def unmap(self, ids):
        return [self.id2unit(idx) for idx in ids]
        
    def build_vocab(self):
        NotImplementedError()
        
    def __len__(self):
        return len(self._unit2id)

# %%
class PretrainedWordVocab(BaseVocab):
    def build_vocab(self):
        self._id2unit = VOCAB_PREFIX + self.data
        self._unit2id = {w:i for i, w in enumerate(self._id2unit)}

# %% [markdown]
# In addition to the pretrained vocab, we are going to create a word vocab that we are going to use to encode the words and the pos tags. It extends the same `BaseVocab` class but has a different way of initialization.
#
# The `self.data` in this vocab is going to be a list of list of lists, like that:
#
# `[[['I', 'PRON'], ['like', 'VERB'], ['cats', 'NOUN'], ['.', 'PUNCT']]]`.
#
# We also added the `idx` parameter for the `BaseVocab` to select the appropriate element for each word array in out data.

# %%
class WordVocab(BaseVocab):
    def build_vocab(self):
        if self.lower:
            counter = Counter([w[self.idx].lower() for sent in self.data for w in sent])
        else:
            counter = Counter([w[self.idx] for sent in self.data for w in sent])

        self._id2unit = VOCAB_PREFIX + list(sorted(list(counter.keys()), key=lambda k: counter[k], reverse=True))
        self._unit2id = {w:i for i, w in enumerate(self._id2unit)}

# %% [markdown]
# ## Building the Dataset
#
# The `Pretrain` class is the same as in the [Lab 5](https://github.com/ckittask/tartu-nlp-2021/tree/main/labs/lab_5).

# %%
class Pretrain:
    def __init__(self, vec_filename, max_vocab=-1):
        self._vec_filename = vec_filename
        self._max_vocab = max_vocab
        
    @property
    def vocab(self):
        if not hasattr(self, '_vocab'):
            self._vocab, self._emb = self.read()
        return self._vocab
    
    @property
    def emb(self):
        if not hasattr(self, '_emb'):
            self._vocab, self._emb = self.read()
        return self._emb
        
    def read(self):
        if self._vec_filename is None:
            raise Exception("Vector file is not provided.")
        print(f"Reading pretrained vectors from {self._vec_filename}...")
        
        words, emb, failed = self.read_from_file(self._vec_filename, open_func=open)
        
        if failed > 0: # recover failure
            emb = emb[:-failed]
        if len(emb) - len(VOCAB_PREFIX) != len(words):
            raise Exception("Loaded number of vectors does not match number of words.")
            
        # Use a fixed vocab size
        if self._max_vocab > len(VOCAB_PREFIX) and self._max_vocab < len(words):
            words = words[:self._max_vocab - len(VOCAB_PREFIX)]
            emb = emb[:self._max_vocab]
                
        vocab = PretrainedWordVocab(words, lower=True)
        
        return vocab, emb
        
    def read_from_file(self, filename, open_func=open):
        """
        Open a vector file using the provided function and read from it.
        """
        first = True
        words = []
        failed = 0
        with open_func(filename, 'rb') as f:
            for i, line in enumerate(f):
                try:
                    line = line.decode()
                except UnicodeDecodeError:
                    failed += 1
                    continue
                if first:
                    # the first line contains the number of word vectors and the dimensionality
                    first = False
                    line = line.strip().split(' ')
                    rows, cols = [int(x) for x in line]
                    emb = np.zeros((rows + len(VOCAB_PREFIX), cols), dtype=np.float32)
                    continue

                line = line.rstrip().split(' ')
                emb[i+len(VOCAB_PREFIX)-1-failed, :] = [float(x) for x in line[-cols:]]
                words.append(' '.join(line[:-cols]))
        return words, emb, failed

# %% [markdown]
# Since our data is in the [CoNLL-U format](https://universaldependencies.org/format.html) that is basically as tab-separated text document, we are going to create `Word`, `Sentence`, `Document` classes to store all the information about words, sentences, documents.
# <img src="https://lh3.googleusercontent.com/pw/ACtC-3f5z2JEt1_k9qc6Po8-HqfcA3WEJzoGPj6cO7XtNklBXpv4PRuDv07JZkw-6r4opzoJjDcPv-r8NAQNsNu-rLfw2MdA0mxefAQ8I_k20kQHU1D-SuEB1LXvQn5fWKAZFBuJkrG_qX0vwhHAJLt5It73qA=w744-h221-no?authuser=0">
#
# `Word` class is just going to store all 10 fields with their respecitve names. These are `id`, `text`, `lemma`, `upos`, `xpos`, `feats`, `head`, `deprel`, `deps`, and `misc`. For this model, we are only interested in `text` and `upos` fields, but it's good idea to have all the information nicely stored in case we want to expand our model (that you are going to do in the homework).
#
# `Sentence` class just stores the list of `Word` objects.
#
# `Document` class stores the list of `Sentence` objects and actually reads the text file in the `load_conll` method. `get` method returns a document as a list of lists of lists that we will need to build a `WordVocab`.

# %%
FIELD_NUM = 10

class Word:
    def __init__(self, word: List[str]):
        self._id = word[0]
        self._text = word[1]
        self._lemma = word[2]
        self._upos = word[3]
        self._xpos = word[4]
        self._feats = word[5]
        self._head = word[6]
        self._deprel = word[7]
        self._deps = word[8]
        self._misc = word[9]

    @property
    def id(self):
        return self._id

    @property
    def text(self):
        return self._text

    @property
    def lemma(self):
        return self._lemma

    @property
    def upos(self):
        return self._upos

    @property
    def xpos(self):
        return self._xpos

    @property
    def feats(self):
        return self._feats

    @property
    def head(self):
        return self._head

    @property
    def deprel(self):
        return self._deprel

    @property
    def deps(self):
        return self._deps

    @property
    def misc(self):
        return self._misc


class Sentence:
    def __init__(self, words: List[List[str]]):
        self._words = [Word(w) for w in words]

    @property
    def words(self):
        return self._words

class Document:
    def __init__(self, file_path):
        self._sentences = []
        self.load_conll(open(file_path, encoding='utf-8'))


    def load_conll(self, f, ignore_gapping=True):
        """ Load the file or string into the CoNLL-U format data.
        Input: file or string reader, where the data is in CoNLL-U format.
        Output: a list of list of list for each token in each sentence in the data, where the innermost list represents 
        all fields of a token.

        Taken and modified from Stanza: https://github.com/stanfordnlp/stanza/blob/master/stanza/utils/conll.py
        Stanza is released under the Apache License, Version 2.0.
        """
        # f is open() or io.StringIO()
        doc, sent = [], []
        for line in f:
            line = line.strip()
            if len(line) == 0:
                if len(sent) > 0:
                    doc.append(Sentence(sent))
                    sent = []
            else:
                if line.startswith('#'): # skip comment line
                    continue
                array = line.split('\t')
                if ignore_gapping and '.' in array[0]:
                    continue
                assert len(array) == FIELD_NUM, \
                        f"Cannot parse CoNLL line: expecting {FIELD_NUM} fields, {len(array)} found."
                sent += [array]
        if len(sent) > 0:
            doc.append(Sentence(sent))
        self._sentences = doc

    
    @property
    def sentences(self):
        return self._sentences


    def get(self, fields, as_sentences=False):
        """Taken and modified from Stanza: https://github.com/stanfordnlp/stanza/blob/master/stanza/models/common/doc.py
        Stanza is released under the Apache License, Version 2.0.
        """
        assert isinstance(fields, list), "Must provide field names as a list."
        assert len(fields) >= 1, "Must have at least one field."

        results = []
        for sentence in self.sentences:
            cursent = []
            units = sentence.words
            for unit in units:
                if len(fields) == 1:
                    cursent += [getattr(unit, fields[0])]
                else:
                    cursent += [[getattr(unit, field) for field in fields]]

            # decide whether append the results as a sentence or a whole list
            if as_sentences:
                results.append(cursent)
            else:
                results += cursent
        return results

# %% [markdown]
# Finally, to read the data, we are going to create `CONLLUDataset` class that implements the [`Dataset`](https://pytorch.org/docs/stable/data.html?highlight=dataset#torch.utils.data.Dataset) class from PyTorch.
#
# First, we are going to initialize the pretrain vocab by calling `pretrain.vocab` and saving it in the `self.pretrain_vocab` variable.
#
# Next, we read the data with `self.load_doc()` method. We are going to pass a `Document` object that we created before to this method.
#
# Then, we initialize the vocabs with the data that we just read with the `self.init_vocab` method and store them inside the `self.vocab` variable.
#
# Finally, we preprocess the data with `self.preprocess` method. In this method, we are turning the words and upos tags into the respective indices in their vocabs.

# %%
class CONLLUDataset(Dataset):
    def __init__(self, doc: Document, pretrain: Pretrain, 
                 vocab: Dict[str, BaseVocab] = None, test: bool = False):
        self.pretrain_vocab = pretrain.vocab
        self.test = test
        data = self.load_doc(doc)

        if vocab is None:
            self.vocab = self.init_vocab(data)
        else:
            self.vocab = vocab

        self.data = self.preprocess(data, self.vocab, self.pretrain_vocab)

    def init_vocab(self, data: List) -> Dict:
        wordvocab = WordVocab(data, idx=0)
        uposvocab = WordVocab(data, idx=1)
        vocab = {
            'word': wordvocab,
            'upos': uposvocab}
        return vocab

    def preprocess(self, data: List, vocab: Dict[str, BaseVocab], 
                   pretrain_vocab: PretrainedWordVocab) -> List[List[int]]:
        processed = []
        for sent in data:
            processed_sent = [vocab['word'].map([w[0] for w in sent])]
            processed_sent += [vocab['upos'].map([w[1] for w in sent])]
            processed_sent += [pretrain_vocab.map([w[0].lower() for w in sent])]
            processed.append(processed_sent)
        return processed
        
    def load_doc(self, doc: Document) -> List:
        data = doc.get(['text', 'upos'], as_sentences=True)
        return data
            
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx]

# %%
pretrain = Pretrain(VEC_PATH, MAX_VOCAB)

# %%
train_doc = Document(DATA_PATH / 'en_gum-ud-train.conllu')
train_dataset = CONLLUDataset(train_doc, pretrain)
# Out:
# Reading pretrained vectors from vector_cache/cc.en.300.vec...

# %% [markdown]
# When creating a development data set, we should use the same vocabs as in the training set so that the mappings from words to ids are the same. We can extract the vocabs from the `train_dataset` by addressing the `vocab` attribute. The pretrained vocab is stored in the `pretrain` object already.

# %%
vocab = train_dataset.vocab
dev_doc = Document(DATA_PATH / 'en_gum-ud-dev.conllu')
dev_dataset = CONLLUDataset(dev_doc, pretrain, vocab=vocab, test=True)

# %%
train_dataset[0]
# Out:
# [[5665, 5666, 6, 473, 794, 43],
#  [9, 2, 12, 9, 2, 3],
#  [9593, 7672, 5, 24248, 724, 12]]

# %% [markdown]
# As usual, we need to specify the `collate_fn` for the [`DataLoader`](https://pytorch.org/docs/stable/data.html?highlight=dataloader#torch.utils.data.DataLoader).
#
# Last time, we padded all the sentences with `0` by hand to make them all equal length and allow constructing the batch matrix. We can do that now but it will create a lot of unnecessary computations for the paddings.
#
# Luckily for us, PyTorch has a [`PackedSequence`](https://pytorch.org/docs/stable/generated/torch.nn.utils.rnn.PackedSequence.html#torch.nn.utils.rnn.PackedSequence) class as well as [`pad_sequence`](https://pytorch.org/docs/stable/generated/torch.nn.utils.rnn.pad_sequence.html), [`pack_padded_sequence`](https://pytorch.org/docs/stable/generated/torch.nn.utils.rnn.pack_padded_sequence.html#torch.nn.utils.rnn.pack_padded_sequence) and [`pad_packed_sequence`](https://pytorch.org/docs/stable/generated/torch.nn.utils.rnn.pad_packed_sequence.html) objects. Let's see what each of them does and how we can benefit from them in our model.
#
# `pad_sequence` function is prettry straightforward. As the name suggests, it pads the sequences to the same length. So, let's say we have $64$ sentences in out batch, all of which are of different length. `pad_sequence` is going to take them as a list of 64 tensors and return a tensor of size $B \times T$, where $B$ is the batch size and $T$ is the length of the longest sentence in the batch.
#
# `pack_padded_sequence` function is going to take our padded sequence as the original lengths of the sequences (i.e. before padding) and return a `PackedSequence` object that we are going to feed to the neural network. As you may notice, we saved the lengths of each sequence in the `sent_lens` before padding. This `PackedSequence` object is going to ensure that our model doesn't perform tons of useless computations on the padding symbols. We can use `PackedSequence` object in the loss function as well.
#
# `pad_packed_sequence` function does the complete opposite of what `pack_padded_sequence` does. It takes a `PackedSequence` object as an input and returns a padded tensor of size $B \times T$.

# %%
a = torch.tensor([1, 2, 3])
b = torch.tensor([1, 2, 3, 4])
c = torch.tensor([1, 2, 3, 4, 5])

packed_sequence = pack_sequence([a, c, b], enforce_sorted=False)
print(packed_sequence)
sequence = pad_packed_sequence(packed_sequence)
print(sequence)
pack_padded_sequence(sequence[0], lengths=sequence[1], enforce_sorted=False)
# Out:
# PackedSequence(data=tensor([1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 5]), batch_sizes=tensor([3, 3, 3, 2, 1]), sorted_indices=tensor([1, 2, 0]), unsorted_indices=tensor([2, 0, 1]))
# (tensor([[1, 1, 1],
#         [2, 2, 2],
#         [3, 3, 3],
#         [0, 4, 4],
#         [0, 5, 0]]), tensor([3, 5, 4]))
# PackedSequence(data=tensor([1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 5]), batch_sizes=tensor([3, 3, 3, 2, 1]), sorted_indices=tensor([1, 2, 0]), unsorted_indices=tensor([2, 0, 1]))

# %%
def pad_collate(batch):
    (sents, upos, pretrained) = zip(*batch)

    sent_lens = [len(s) for s in sents] 

    sents = [torch.LongTensor(w).to(device) for w in sents]
    upos = [torch.LongTensor(tag).to(device) for tag in upos]
    pretrained = [torch.LongTensor(pt).to(device) for pt in pretrained]

    sent_pad = pad_sequence(sents, batch_first=True, padding_value=PAD_ID).to(device)
    upos_pad = pad_sequence(upos, batch_first=True, padding_value=PAD_ID).to(device)
    pretrained_pad = pad_sequence(pretrained, batch_first=True, padding_value=PAD_ID).to(device)


    return sent_pad, upos_pad, pretrained_pad, sent_lens

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle_dataset, collate_fn=pad_collate)

# %%
dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=shuffle_dataset, collate_fn=pad_collate)

# %% [markdown]
# ## Define the model
#
# To better understand the model architecture, it's better to make a visual representation of it.

# %% [markdown]
# ![image.png](https://github.com/501Good/tartu-nlp-2020/blob/master/labs/lab5/img2.png?raw=1)

# %% [markdown]
# As we can see, the model will have two embedding layers, one is going to be trainable and another one is going to stay frozen and contained already pretrained word vectors that we downloaded before.
#
# Then, we have a BiLSTM layer which stands for a Bidirectional LSTM. You can see it simply as two LSTM layers but one is passing the hidden states from left to right and another one from right to left. You can see the comparison of LSTM and BiLSTM on the picture below:
#
# ![BiLSTM vs LSTM](https://www.researchgate.net/profile/Arvind_Mohan/publication/324769532/figure/fig2/AS:619510805561344@1524714294669/LSTM-and-BiLSTM-Architectures.png)
# Image from: *Mohan, Arvind & Gaitonde, Datta. (2018). A Deep Learning based Approach to Reduced Order Modeling for Turbulent Flow Control using LSTM Neural Networks.*
#
# Finally, we have two [Linear layers](https://pytorch.org/docs/stable/nn.html?highlight=linear#torch.nn.Linear) with a [ReLU activation function](https://pytorch.org/docs/stable/nn.html#torch.nn.ReLU) in-between that are going to map the output of the LSTM layer to the probabilities of each pos tag. Since each word can have one and only one pos tag, we will just take the index of the maximum probability to make the prediction.
#
# To optimize the model, we use [cross-entropy loss](https://pytorch.org/docs/stable/nn.html?highlight=crossentropy#torch.nn.CrossEntropyLoss) fucntion. Since we give a `PackedSequence` as an input to the model, the output will also be a `PackedSequence`. That means that we also need to transform the correct tags to a `PackedSequence` and take the `data` attribute from it to match the output of the model.
#
# Also, the model has many tricky transformations to fit the data into the correct modules. Let's go line by line in the `forward()` method.
#
# First, we create an `inputs = []` list to store our inputs. Then, we get the trainable word embeddings for our first input with `self.word_emb`. We repeat the same for the `self.pretrained_emb` with the only difference that we put the embeddings through the linear layer to transform them to the dimension that we want.
#
# After that, we need to concatenate the inputs. We basically add a pretrained embedding to the end of the word embedding. Finally, we pack the inputs to put the into the LSTM. Pay attention that we specify `enforce_sorted = False` flag because we didn't sort the sentences by length inside of the batch.
#
# Now, we can finally put all of that into the `self.lstm` layer. We take the `data` from the output, which is also a `PackedSequence`. We do it because we don't want to perform extra operations on the padding in the linear layers and `PackedSequence` inputs are only supported by RNNs. To overcome this, we create a `PackedSequence` from the linear output manually. Even though the PyTorch documentation [strongly recommends against creaing a `PackedSequence` manually](https://pytorch.org/docs/stable/generated/torch.nn.utils.rnn.PackedSequence.html#torch.nn.utils.rnn.PackedSequence), it seems to be the only workaround for now. It is important that you don't forget to put all the parameters from the original packed sequence like `batch_sizes`, `sorted_indices`, and `unsorted_indices`. If you don't specify the last two, `pad_packed_sequence()` function is going to sort your predictions automatically, and thus you will lose the correct order of your predictions and they become practically useless.
#
# Finally, we take the index with maximum probability for each prediction which is going to be the index of the pos tag in the vocabulary. The last step is calculate the loss.

# %%
class Tagger(nn.Module):
    def __init__(self, vocab: Dict[str, BaseVocab], word_emb_dim: int,
                 transformed_dim: int, emb_matrix: np.ndarray, hidden_dim: int,
                 upos_clf_hidden_dim: int, num_layers: int, dropout: int):
        super().__init__()

        self.vocab = vocab
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim

        input_size = 0

        self.word_emb = nn.Embedding(len(vocab['word']), word_emb_dim, padding_idx=0)
        input_size += word_emb_dim

        self.pretrained_emb = nn.Embedding.from_pretrained(torch.from_numpy(emb_matrix), freeze=True)
        self.trans_pretrained = nn.Linear(emb_matrix.shape[1], transformed_dim, bias=False)
        input_size += transformed_dim

        self.lstm = nn.LSTM(input_size, hidden_dim, num_layers, batch_first=True, dropout=dropout,bidirectional=True  )
        
        
        self.lstm_h_init = nn.Parameter(torch.zeros(num_layers*2, 1, hidden_dim))
        self.lstm_c_init = nn.Parameter(torch.zeros(num_layers*2, 1, hidden_dim))

        self.upos_hid = nn.Linear(2* hidden_dim, upos_clf_hidden_dim)
        self.upos_clf = nn.Linear(upos_clf_hidden_dim, len(vocab['upos']))

        self.crit = nn.CrossEntropyLoss(ignore_index=0)

        self.drop = nn.Dropout(dropout)

    
    def forward(self, sent_pad, upos_pad, pretrained_pad, sent_lens):
        inputs = []

        word_emb = self.word_emb(sent_pad)
        inputs += [word_emb]

        pretrained_emb = self.pretrained_emb(pretrained_pad)
        pretrained_emb = self.trans_pretrained(pretrained_emb)
        inputs += [pretrained_emb]
   
   
        # concatenate the given sequence in the given dimension 
        lstm_inputs = torch.cat(inputs, 2)

        # dropout does not take PackedSequence as an input, so we apply it before
        lstm_inputs = self.drop(lstm_inputs)
        # pack the input
        lstm_inputs = pack_padded_sequence(lstm_inputs, sent_lens, batch_first=True, enforce_sorted=False)
        # self.lstm_h_init - tensor containing the initial hidden state for each element in the batch
        # self.lstm_c_init - tensor containing the initial cell state for each element in the batch
        # 2 is for bidirectionality 
        # calling contiguous - Returns a contiguous in memory tensor containing the same data as self tensor
        lstm_outputs, _ = self.lstm(
            lstm_inputs, 
            (self.lstm_h_init.expand(2*self.num_layers, sent_pad.size(0), self.hidden_dim).contiguous(), 
             self.lstm_c_init.expand(2*self.num_layers, sent_pad.size(0), self.hidden_dim).contiguous())
        )
        lstm_outputs = lstm_outputs.data

        upos_hid = F.relu(self.upos_hid(self.drop(lstm_outputs)))
        upos_pred = self.upos_clf(self.drop(upos_hid))
        # create PackedSequence 
        pred = PackedSequence(upos_pred, lstm_inputs.batch_sizes, lstm_inputs.sorted_indices, lstm_inputs.unsorted_indices )
        pred = pad_packed_sequence(pred, batch_first=True)[0]
        pred = pred.max(2)[1]
        upos = pack_padded_sequence(upos_pad, sent_lens, batch_first=True, enforce_sorted=False).data
        loss = self.crit(upos_pred, upos)

        return loss, pred

# %%
x = torch.randn(2,2,2)
y = torch.randn(2,2,2)
print(x)
print(y)
torch.cat([x,y],2)
# Out:
# tensor([[[-0.7558,  1.0792],
#          [-0.5296, -1.6815]],
#
#         [[ 0.3268,  0.4326],
#          [ 0.6378,  1.7213]]])
# tensor([[[-0.5925,  2.5252],
#          [-0.2452, -0.0279]],
#
#         [[-0.2194,  0.9246],
#          [-0.0030, -1.2845]]])
# tensor([[[-0.7558,  1.0792, -0.5925,  2.5252],
#          [-0.5296, -1.6815, -0.2452, -0.0279]],
#
#         [[ 0.3268,  0.4326, -0.2194,  0.9246],
#          [ 0.6378,  1.7213, -0.0030, -1.2845]]])

# %% [markdown]
# In the `Trainer` class, we are going to update the model's weights in the `update()` method. This method performs the forward pass of the model, backward pass on the loss and updates the optimizer.
#
# `predict()` method is used for inference. It only performs the forward pass on the model and trims the predictions to their original lengths.

# %%
class Trainer:
    def __init__(self, vocab, word_emb_dim, transformed_dim, emb_matrix, hidden_dim, upos_clf_hidden_dim, num_layers, dropout, use_cuda=False):
        self.use_cuda = use_cuda

        self.vocab = vocab
        self.model = Tagger(vocab, word_emb_dim, transformed_dim, emb_matrix, hidden_dim, upos_clf_hidden_dim, num_layers, dropout)
        self.parameters = [p for p in self.model.parameters() if p.requires_grad]

        self.model.to(device)

        self.optimizer = torch.optim.Adam(self.parameters)
 
    def update(self, batch, eval=False):
        sent_pad, upos_pad, pretrained_pad, sent_lens = batch

        if eval:
            self.model.eval()
        else:
            self.model.train()
            self.optimizer.zero_grad()

        loss, _ = self.model(sent_pad, upos_pad, pretrained_pad, sent_lens)
        loss_val = loss.data.item()
        if eval:
            return loss_val

        loss.backward()
        self.optimizer.step()

        return loss_val


    def predict(self, batch):
        sent_pad, upos_pad, pretrained_pad, sent_lens = batch

        self.model.eval()
        batch_size = sent_pad.size(0)
        _, pred = self.model(sent_pad, upos_pad, pretrained_pad, sent_lens)
        # Transform the indices to the pos tags
        pred = [self.vocab['upos'].unmap(sent) for sent in pred.tolist()]
        # Trim the predictions to their original lengths
        pred_tokens = [[pred[i][j] for j in range(sent_lens[i])] for i in range(batch_size)]

        return pred_tokens

# %%
word_emb_dim = 75
transformed_dim = 125
emb_matrix = pretrain.emb
hidden_dim = 200
upos_clf_hidden_dim = 400
num_layers = 2
dropout = 0.5
use_cuda = True if device == 'cuda' else False

# %%
trainer = Trainer(vocab, word_emb_dim, transformed_dim, emb_matrix, hidden_dim, upos_clf_hidden_dim, num_layers, dropout, use_cuda)

# %%
global_step = 0
max_steps = 50000
dev_score_history = []
format_str = '{}: step {}/{}, loss = {:.6f} ({:.3f} sec/batch)'
last_best_step = 0

log_step = 20
eval_interval = 100

# %% [markdown]
# We will train the model for 50000 steps. A training step is one gradient update, whereas one epoch is one complete pass through the training data.

# %%
train_loss = 0
while True:
    do_break = False
    for batch in train_loader:
        start_time = time()

        global_step += 1
        loss = trainer.update(batch, eval=False)
        train_loss += loss

        if global_step % log_step == 0:
            duration = time() - start_time
            print(format_str.format(datetime.now().strftime("%Y-%m-%d %H:%M:%S"), global_step,\
                    max_steps, loss, duration))
            
        if global_step % eval_interval == 0:
            print("Evaluating on dev set...")
            dev_preds = []
            dev_words = []
            for batch in dev_loader:
                batch_size = batch[0].size(0)
                preds = trainer.predict(batch)
                dev_preds += preds
                # Keep the original sentence
                pred_sents = [[batch[0][i][j] for j in range(batch[3][i])] for i in range(batch_size)]
                dev_words += [vocab['word'].unmap(sent) for sent in [sent for sent in pred_sents]]
            
            train_loss = train_loss / eval_interval
            print("step {}: train_loss = {:.6f}".format(global_step, train_loss))
            # Shows one prediction for a sanity check
            print(f"Preds: {list(zip(dev_preds[0], dev_words[0]))}")
            train_loss = 0

        if global_step >= max_steps:
            do_break = True
            break

        if do_break:
            break
# Out:
# Streaming output truncated to the last 5000 lines.
# 2021-04-06 15:07:22: step 66920/50000, loss = 0.003208 (0.021 sec/batch)
# 2021-04-06 15:07:23: step 66940/50000, loss = 0.003064 (0.020 sec/batch)
# 2021-04-06 15:07:23: step 66960/50000, loss = 0.011002 (0.023 sec/batch)
# 2021-04-06 15:07:24: step 66980/50000, loss = 0.001285 (0.017 sec/batch)
# 2021-04-06 15:07:24: step 67000/50000, loss = 0.004347 (0.018 sec/batch)
# Evaluating on dev set...
# step 67000: train_loss = 0.007115
# Preds: [('SCONJ', 'Although'), ('PRON', 'they'), ('AUX', 'are'), ('ADV', 'now'), ('VERB', '<UNK>'), ('PUNCT', '('), ('ADP', 'with'), ('DET', 'the'), ('ADJ', 'young'), ('VERB', 'using'), ('NOUN', 'cell'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('X', 'etc.'), ('PUNCT', ')'), ('PUNCT', ','), ('PRON', 'they'), ('VERB', 'maintain'), ('ADJ', 'many'), ('ADP', 'of'), ('PRON', 'their'), ('ADJ', 'old'), ('NOUN', 'customs'), ('PUNCT', ','), ('NOUN', 'traditions'), ('CCONJ', 'and'), ('NOUN', 'beliefs'), ('PUNCT', '.')]
# 2021-04-06 15:07:25: step 67020/50000, loss = 0.003497 (0.019 sec/batch)
# 2021-04-06 15:07:26: step 67040/50000, loss = 0.011142 (0.021 sec/batch)
# 2021-04-06 15:07:26: step 67060/50000, loss = 0.005792 (0.028 sec/batch)
# 2021-04-06 15:07:27: step 67080/50000, loss = 0.003095 (0.021 sec/batch)
# 2021-04-06 15:07:27: step 67100/50000, loss = 0.006113 (0.021 sec/batch)
# Evaluating on dev set...
# step 67100: train_loss = 0.006440
# Preds: [('ADV', '<UNK>'), ('PUNCT', ','), ('ADV', '<UNK>'), ('PUNCT', ','), ('PRON', 'we'), ('AUX', 'do'), ('ADV', '<UNK>'), ('VERB', '<UNK>'), ('CCONJ', 'and'), ('ADJ', '<UNK>'), ('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PRON', 'our'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADV', 'immediately'), ('ADP', 'upon'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PRON', 'this'), ('PUNCT', ','), ('PRON', 'our'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('PART', 'to'), ('VERB', 'proceed'), ('ADP', 'with'), ('DET', 'a'), ('ADJ', '<UNK>'), ('NOUN', 'force'), ('CCONJ', 'and'), ('ADJ', 'clear'), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PROPN', 'Congress'), ('PUNCT', '.')]
# 2021-04-06 15:07:28: step 67120/50000, loss = 0.002789 (0.022 sec/batch)
# 2021-04-06 15:07:29: step 67140/50000, loss = 0.006151 (0.024 sec/batch)
# 2021-04-06 15:07:29: step 67160/50000, loss = 0.011091 (0.018 sec/batch)
# 2021-04-06 15:07:30: step 67180/50000, loss = 0.007438 (0.021 sec/batch)
# 2021-04-06 15:07:31: step 67200/50000, loss = 0.002762 (0.027 sec/batch)
# Evaluating on dev set...
# step 67200: train_loss = 0.006622
# Preds: [('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PROPN', 'Mosque'), ('PUNCT', ','), ('NOUN', 'interior'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', '<UNK>')]
# 2021-04-06 15:07:32: step 67220/50000, loss = 0.000461 (0.025 sec/batch)
# 2021-04-06 15:07:32: step 67240/50000, loss = 0.001975 (0.027 sec/batch)
# 2021-04-06 15:07:33: step 67260/50000, loss = 0.012082 (0.026 sec/batch)
# 2021-04-06 15:07:33: step 67280/50000, loss = 0.010491 (0.027 sec/batch)
# 2021-04-06 15:07:34: step 67300/50000, loss = 0.008695 (0.018 sec/batch)
# Evaluating on dev set...
# step 67300: train_loss = 0.006055
# Preds: [('PUNCT', '"'), ('PRON', 'I'), ('VERB', 'suspect'), ('PRON', 'they'), ('AUX', 'wo'), ('PART', "n't"), ('VERB', 'do'), ('PRON', 'that'), ('ADP', 'on'), ('DET', 'a'), ('ADJ', '<UNK>'), ('NOUN', 'basis'), ('PUNCT', ','), ('PRON', 'we'), ('AUX', "'ve"), ('VERB', 'tried'), ('ADV', 'so'), ('ADV', 'far'), ('CCONJ', 'and'), ('AUX', 'have'), ('PART', "n't"), ('VERB', '<UNK>'), ('PUNCT', ','), ('ADV', 'so'), ('PRON', 'we'), ('AUX', "'ve"), ('VERB', 'convinced'), ('DET', 'the'), ('NOUN', 'Food'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PROPN', 'Australia'), ('CCONJ', 'and'), ('PROPN', 'New'), ('PROPN', 'Zealand'), ('PUNCT', '<UNK>'), ('SCONJ', 'that'), ('DET', 'all'), ('NOUN', 'salt'), ('AUX', 'should'), ('AUX', 'be'), ('VERB', '<UNK>'), ('PUNCT', ','), ('PUNCT', '"'), ('PRON', 'he'), ('VERB', 'said'), ('PUNCT', '.')]
# 2021-04-06 15:07:35: step 67320/50000, loss = 0.006492 (0.018 sec/batch)
# 2021-04-06 15:07:35: step 67340/50000, loss = 0.007168 (0.020 sec/batch)
# 2021-04-06 15:07:36: step 67360/50000, loss = 0.006476 (0.021 sec/batch)
# 2021-04-06 15:07:36: step 67380/50000, loss = 0.006996 (0.019 sec/batch)
# 2021-04-06 15:07:37: step 67400/50000, loss = 0.013933 (0.021 sec/batch)
# Evaluating on dev set...
# step 67400: train_loss = 0.006539
# Preds: [('PUNCT', '"'), ('PROPN', 'Daniel'), ('AUX', 'was'), ('VERB', 'picked'), ('ADP', 'up'), ('ADP', 'by'), ('DET', 'an'), ('NOUN', '<UNK>'), ('ADP', 'in'), ('DET', 'a'), ('ADJ', 'black'), ('NOUN', 'car'), ('ADP', 'with'), ('NOUN', '<UNK>'), ('ADP', 'out'), ('NOUN', 'windows'), ('PUNCT', '.')]
# 2021-04-06 15:07:38: step 67420/50000, loss = 0.004537 (0.022 sec/batch)
# 2021-04-06 15:07:38: step 67440/50000, loss = 0.002715 (0.020 sec/batch)
# 2021-04-06 15:07:39: step 67460/50000, loss = 0.002398 (0.020 sec/batch)
# 2021-04-06 15:07:40: step 67480/50000, loss = 0.015864 (0.021 sec/batch)
# 2021-04-06 15:07:40: step 67500/50000, loss = 0.003479 (0.023 sec/batch)
# Evaluating on dev set...
# step 67500: train_loss = 0.006610
# Preds: [('AUX', 'Do'), ('PART', 'not'), ('VERB', 'drink'), ('SCONJ', 'if'), ('NOUN', '<UNK>'), ('ADP', 'in'), ('PRON', 'your'), ('NOUN', 'country'), ('PUNCT', '.')]
# 2021-04-06 15:07:41: step 67520/50000, loss = 0.007934 (0.021 sec/batch)
# 2021-04-06 15:07:42: step 67540/50000, loss = 0.008744 (0.021 sec/batch)
# 2021-04-06 15:07:42: step 67560/50000, loss = 0.017467 (0.020 sec/batch)
# 2021-04-06 15:07:43: step 67580/50000, loss = 0.004522 (0.025 sec/batch)
# 2021-04-06 15:07:43: step 67600/50000, loss = 0.010677 (0.020 sec/batch)
# Evaluating on dev set...
# step 67600: train_loss = 0.007647
# Preds: [('ADP', 'In'), ('DET', 'the'), ('NOUN', '1960s'), ('CCONJ', 'and'), ('NOUN', '1970s'), ('PUNCT', ','), ('ADJ', 'many'), ('ADJ', '19th'), ('NOUN', 'century'), ('NOUN', '<UNK>'), ('NOUN', 'buildings'), ('PUNCT', ','), ('ADV', 'often'), ('ADJ', 'small'), ('CCONJ', 'and'), ('ADJ', 'private'), ('PUNCT', ','), ('AUX', 'were'), ('VERB', '<UNK>'), ('PART', 'to'), ('VERB', 'make'), ('NOUN', 'way'), ('ADP', 'for'), ('NOUN', 'office'), ('NOUN', 'buildings'), ('PUNCT', ','), ('ADV', 'often'), ('VERB', 'designed'), ('ADP', 'by'), ('ADJ', 'great'), ('ADJ', 'Greek'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:07:44: step 67620/50000, loss = 0.004546 (0.021 sec/batch)
# 2021-04-06 15:07:45: step 67640/50000, loss = 0.011899 (0.024 sec/batch)
# 2021-04-06 15:07:45: step 67660/50000, loss = 0.009039 (0.022 sec/batch)
# 2021-04-06 15:07:46: step 67680/50000, loss = 0.002567 (0.019 sec/batch)
# 2021-04-06 15:07:46: step 67700/50000, loss = 0.002314 (0.024 sec/batch)
# Evaluating on dev set...
# step 67700: train_loss = 0.006081
# Preds: [('NUM', 'Two'), ('NOUN', '<UNK>'), ('PUNCT', ':')]
# 2021-04-06 15:07:47: step 67720/50000, loss = 0.019606 (0.026 sec/batch)
# 2021-04-06 15:07:48: step 67740/50000, loss = 0.006105 (0.022 sec/batch)
# 2021-04-06 15:07:48: step 67760/50000, loss = 0.003134 (0.020 sec/batch)
# 2021-04-06 15:07:49: step 67780/50000, loss = 0.011840 (0.021 sec/batch)
# 2021-04-06 15:07:49: step 67800/50000, loss = 0.016147 (0.022 sec/batch)
# Evaluating on dev set...
# step 67800: train_loss = 0.007860
# Preds: [('DET', 'A'), ('ADJ', 'yellow'), ('NOUN', 'man'), ('PUNCT', '!')]
# 2021-04-06 15:07:50: step 67820/50000, loss = 0.003021 (0.026 sec/batch)
# 2021-04-06 15:07:51: step 67840/50000, loss = 0.004710 (0.027 sec/batch)
# 2021-04-06 15:07:52: step 67860/50000, loss = 0.000590 (0.020 sec/batch)
# 2021-04-06 15:07:52: step 67880/50000, loss = 0.001425 (0.021 sec/batch)
# 2021-04-06 15:07:53: step 67900/50000, loss = 0.003872 (0.025 sec/batch)
# Evaluating on dev set...
# step 67900: train_loss = 0.006315
# Preds: [('DET', 'The'), ('NOUN', 'city'), ('VERB', '<UNK>'), ('PRON', 'its'), ('NOUN', 'importance'), ('ADP', 'in'), ('ADJ', 'Greek'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('CCONJ', 'and'), ('ADP', 'by'), ('NUM', '1900'), ('AUX', 'had'), ('VERB', 'evolved'), ('ADP', 'into'), ('DET', 'a'), ('ADV', 'very'), ('ADJ', 'attractive'), ('ADJ', 'cosmopolitan'), ('NOUN', 'city'), ('PUNCT', ','), ('ADP', 'with'), ('ADJ', 'abundant'), ('ADJ', '<UNK>'), ('NOUN', 'architecture'), ('VERB', '<UNK>'), ('ADP', 'to'), ('DET', 'the'), ('NOUN', 'nation'), ('PART', "'s"), ('NOUN', 'past'), ('PUNCT', '.')]
# 2021-04-06 15:07:54: step 67920/50000, loss = 0.005911 (0.021 sec/batch)
# 2021-04-06 15:07:54: step 67940/50000, loss = 0.004471 (0.027 sec/batch)
# 2021-04-06 15:07:55: step 67960/50000, loss = 0.003344 (0.023 sec/batch)
# 2021-04-06 15:07:55: step 67980/50000, loss = 0.006990 (0.021 sec/batch)
# 2021-04-06 15:07:56: step 68000/50000, loss = 0.002373 (0.020 sec/batch)
# Evaluating on dev set...
# step 68000: train_loss = 0.006897
# Preds: [('ADV', 'Never'), ('VERB', 'drink'), ('CCONJ', 'and'), ('VERB', 'drive'), ('PUNCT', '.')]
# 2021-04-06 15:07:57: step 68020/50000, loss = 0.006185 (0.020 sec/batch)
# 2021-04-06 15:07:57: step 68040/50000, loss = 0.012851 (0.017 sec/batch)
# 2021-04-06 15:07:58: step 68060/50000, loss = 0.009472 (0.022 sec/batch)
# 2021-04-06 15:07:58: step 68080/50000, loss = 0.009378 (0.019 sec/batch)
# 2021-04-06 15:07:59: step 68100/50000, loss = 0.006496 (0.023 sec/batch)
# Evaluating on dev set...
# step 68100: train_loss = 0.007964
# Preds: [('ADV', 'However'), ('PUNCT', ','), ('ADV', '<UNK>'), ('PUNCT', ','), ('PRON', 'there'), ('AUX', 'have'), ('VERB', 'been'), ('ADJ', 'several'), ('NOUN', 'events'), ('PRON', 'that'), ('AUX', 'should'), ('VERB', 'cause'), ('DET', 'a'), ('ADJ', '<UNK>'), ('NOUN', 'response'), ('PUNCT', '.')]
# 2021-04-06 15:08:00: step 68120/50000, loss = 0.001096 (0.027 sec/batch)
# 2021-04-06 15:08:00: step 68140/50000, loss = 0.003508 (0.018 sec/batch)
# 2021-04-06 15:08:01: step 68160/50000, loss = 0.008383 (0.018 sec/batch)
# 2021-04-06 15:08:01: step 68180/50000, loss = 0.011893 (0.020 sec/batch)
# 2021-04-06 15:08:02: step 68200/50000, loss = 0.014154 (0.027 sec/batch)
# Evaluating on dev set...
# step 68200: train_loss = 0.007503
# Preds: [('DET', 'The'), ('PROPN', '<UNK>'), ('VERB', 'has'), ('DET', 'a'), ('NOUN', '<UNK>'), ('NOUN', 'pocket'), ('CCONJ', 'and'), ('DET', 'a'), ('NOUN', 'watch'), ('NOUN', 'pocket'), ('PUNCT', '.')]
# 2021-04-06 15:08:03: step 68220/50000, loss = 0.003022 (0.028 sec/batch)
# 2021-04-06 15:08:03: step 68240/50000, loss = 0.013007 (0.021 sec/batch)
# 2021-04-06 15:08:04: step 68260/50000, loss = 0.007753 (0.020 sec/batch)
# 2021-04-06 15:08:05: step 68280/50000, loss = 0.003976 (0.021 sec/batch)
# 2021-04-06 15:08:05: step 68300/50000, loss = 0.023005 (0.019 sec/batch)
# Evaluating on dev set...
# step 68300: train_loss = 0.006235
# Preds: [('DET', 'A'), ('ADJ', 'yellow'), ('NOUN', 'man'), ('PUNCT', '!')]
# 2021-04-06 15:08:06: step 68320/50000, loss = 0.005264 (0.022 sec/batch)
# 2021-04-06 15:08:07: step 68340/50000, loss = 0.016608 (0.023 sec/batch)
# 2021-04-06 15:08:07: step 68360/50000, loss = 0.007947 (0.021 sec/batch)
# 2021-04-06 15:08:08: step 68380/50000, loss = 0.002448 (0.020 sec/batch)
# 2021-04-06 15:08:08: step 68400/50000, loss = 0.014336 (0.020 sec/batch)
# Evaluating on dev set...
# step 68400: train_loss = 0.007879
# Preds: [('PRON', 'I'), ('VERB', 'wanted'), ('PART', 'to'), ('AUX', 'be'), ('NUM', 'seven'), ('ADV', 'again'), ('PUNCT', ','), ('CCONJ', 'and'), ('ADJ', 'safe'), ('PUNCT', '.')]
# 2021-04-06 15:08:09: step 68420/50000, loss = 0.004930 (0.018 sec/batch)
# 2021-04-06 15:08:10: step 68440/50000, loss = 0.000712 (0.018 sec/batch)
# 2021-04-06 15:08:10: step 68460/50000, loss = 0.007978 (0.022 sec/batch)
# 2021-04-06 15:08:11: step 68480/50000, loss = 0.006577 (0.019 sec/batch)
# 2021-04-06 15:08:11: step 68500/50000, loss = 0.007164 (0.021 sec/batch)
# Evaluating on dev set...
# step 68500: train_loss = 0.005835
# Preds: [('DET', 'A'), ('ADJ', 'new'), ('NOUN', 'study'), ('VERB', 'documenting'), ('ADJ', '<UNK>'), ('ADJ', 'nutritional'), ('NOUN', 'status'), ('ADP', 'in'), ('ADJ', 'Australian'), ('NOUN', 'school'), ('NOUN', 'children'), ('AUX', 'has'), ('VERB', 'revealed'), ('ADJ', 'many'), ('AUX', 'are'), ('PART', 'not'), ('VERB', 'getting'), ('ADJ', 'enough'), ('NOUN', '<UNK>'), ('PUNCT', '-'), ('PRON', 'which'), ('AUX', 'can'), ('VERB', 'lead'), ('ADP', 'to'), ('ADJ', 'mental'), ('CCONJ', 'and'), ('NOUN', 'growth'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:08:12: step 68520/50000, loss = 0.002700 (0.017 sec/batch)
# 2021-04-06 15:08:13: step 68540/50000, loss = 0.008869 (0.024 sec/batch)
# 2021-04-06 15:08:13: step 68560/50000, loss = 0.001602 (0.026 sec/batch)
# 2021-04-06 15:08:14: step 68580/50000, loss = 0.004112 (0.024 sec/batch)
# 2021-04-06 15:08:15: step 68600/50000, loss = 0.017653 (0.017 sec/batch)
# Evaluating on dev set...
# step 68600: train_loss = 0.006442
# Preds: [('PROPN', '<UNK>'), ('NOUN', '<UNK>'), ('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PUNCT', ','), ('DET', 'the'), ('PROPN', 'Netherlands')]
# 2021-04-06 15:08:15: step 68620/50000, loss = 0.002517 (0.026 sec/batch)
# 2021-04-06 15:08:16: step 68640/50000, loss = 0.014219 (0.026 sec/batch)
# 2021-04-06 15:08:17: step 68660/50000, loss = 0.003612 (0.021 sec/batch)
# 2021-04-06 15:08:17: step 68680/50000, loss = 0.005637 (0.022 sec/batch)
# 2021-04-06 15:08:18: step 68700/50000, loss = 0.017994 (0.022 sec/batch)
# Evaluating on dev set...
# step 68700: train_loss = 0.006941
# Preds: [('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PUNCT', ','), ('PRON', 'he'), ('AUX', "'s"), ('VERB', 'coming'), ('ADP', 'on'), ('NOUN', 'board'), ('PUNCT', ','), ('PRON', 'he'), ('VERB', 'has'), ('DET', 'some'), ('NOUN', 'ideas'), ('ADP', 'for'), ('PRON', 'that'), ('ADV', 'too'), ('PUNCT', ','), ('PRON', 'he'), ('VERB', 'wants'), ('PART', 'to'), ('VERB', 'take'), ('ADP', 'over'), ('PUNCT', '"'), ('VERB', '<UNK>'), ('PUNCT', '"'), ('CCONJ', 'and'), ('VERB', 'do'), ('ADJ', 'more'), ('NOUN', '<UNK>'), ('NOUN', 'news'), ('PUNCT', '.')]
# 2021-04-06 15:08:19: step 68720/50000, loss = 0.003131 (0.021 sec/batch)
# 2021-04-06 15:08:19: step 68740/50000, loss = 0.008991 (0.025 sec/batch)
# 2021-04-06 15:08:20: step 68760/50000, loss = 0.004631 (0.018 sec/batch)
# 2021-04-06 15:08:20: step 68780/50000, loss = 0.004612 (0.024 sec/batch)
# 2021-04-06 15:08:21: step 68800/50000, loss = 0.001298 (0.026 sec/batch)
# Evaluating on dev set...
# step 68800: train_loss = 0.006912
# Preds: [('ADV', '<UNK>'), ('VERB', 'requested'), ('NOUN', 'donations'), ('ADP', 'via'), ('DET', 'a'), ('NOUN', 'statement'), ('VERB', 'made'), ('ADP', 'on'), ('PRON', 'his'), ('NOUN', 'blog'), ('PUNCT', ','), ('SCONJ', 'in'), ('NOUN', 'order'), ('PART', 'to'), ('VERB', 'help'), ('NOUN', '<UNK>'), ('ADP', 'with'), ('PRON', 'his'), ('ADJ', 'legal'), ('NOUN', 'defense'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:08:22: step 68820/50000, loss = 0.005109 (0.023 sec/batch)
# 2021-04-06 15:08:22: step 68840/50000, loss = 0.006051 (0.020 sec/batch)
# 2021-04-06 15:08:23: step 68860/50000, loss = 0.002156 (0.021 sec/batch)
# 2021-04-06 15:08:23: step 68880/50000, loss = 0.015962 (0.019 sec/batch)
# 2021-04-06 15:08:24: step 68900/50000, loss = 0.016949 (0.022 sec/batch)
# Evaluating on dev set...
# step 68900: train_loss = 0.006612
# Preds: [('PRON', 'it'), ('AUX', '’s'), ('VERB', 'placing'), ('DET', 'these'), ('NUM', 'two'), ('ADJ', '<UNK>'), ('NOUN', 'elements'), ('NOUN', 'side'), ('ADP', 'by'), ('NOUN', 'side'), ('PRON', 'that'), ('VERB', 'makes'), ('DET', 'the'), ('NOUN', 'joke'), ('ADJ', 'funny'), ('PUNCT', '.'), ('PUNCT', '['), ('NUM', '4'), ('PUNCT', ']')]
# 2021-04-06 15:08:25: step 68920/50000, loss = 0.003324 (0.026 sec/batch)
# 2021-04-06 15:08:26: step 68940/50000, loss = 0.002758 (0.027 sec/batch)
# 2021-04-06 15:08:26: step 68960/50000, loss = 0.001282 (0.022 sec/batch)
# 2021-04-06 15:08:27: step 68980/50000, loss = 0.008244 (0.023 sec/batch)
# 2021-04-06 15:08:27: step 69000/50000, loss = 0.007531 (0.022 sec/batch)
# Evaluating on dev set...
# step 69000: train_loss = 0.006806
# Preds: [('PRON', 'What'), ('PRON', 'you'), ('AUX', 'do'), ('PART', 'n’t'), ('VERB', 'want'), ('PART', 'to'), ('VERB', 'wash'), ('ADP', 'with'), ('PRON', 'them'), ('AUX', 'is'), ('NOUN', 'anything'), ('PRON', 'that'), ('AUX', 'can'), ('VERB', 'get'), ('VERB', 'twisted'), ('ADP', 'up'), ('ADP', 'with'), ('DET', 'the'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADP', 'like'), ('NOUN', 'women'), ('PART', '’s'), ('ADJ', 'long'), ('NOUN', 'sleeve'), ('NOUN', 'shirts'), ('CCONJ', 'or'), ('NOUN', 'kids'), ('PART', '’'), ('NOUN', 'blankets'), ('PUNCT', '.')]
# 2021-04-06 15:08:28: step 69020/50000, loss = 0.005047 (0.023 sec/batch)
# 2021-04-06 15:08:29: step 69040/50000, loss = 0.002236 (0.022 sec/batch)
# 2021-04-06 15:08:29: step 69060/50000, loss = 0.002750 (0.020 sec/batch)
# 2021-04-06 15:08:30: step 69080/50000, loss = 0.002558 (0.029 sec/batch)
# 2021-04-06 15:08:30: step 69100/50000, loss = 0.004182 (0.023 sec/batch)
# Evaluating on dev set...
# step 69100: train_loss = 0.006469
# Preds: [('SCONJ', 'When'), ('DET', 'this'), ('VERB', 'failed'), ('PUNCT', ','), ('PRON', 'they'), ('VERB', 'appointed'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADP', 'with'), ('DET', 'a'), ('NOUN', '<UNK>'), ('PART', 'to'), ('VERB', 'create'), ('DET', 'a'), ('ADJ', 'new'), ('NOUN', '<UNK>'), ('PUNCT', '('), ('PROPN', '<UNK>'), ('PUNCT', ')'), ('PUNCT', '.')]
# 2021-04-06 15:08:31: step 69120/50000, loss = 0.001768 (0.020 sec/batch)
# 2021-04-06 15:08:32: step 69140/50000, loss = 0.006753 (0.018 sec/batch)
# 2021-04-06 15:08:32: step 69160/50000, loss = 0.002853 (0.019 sec/batch)
# 2021-04-06 15:08:33: step 69180/50000, loss = 0.016156 (0.029 sec/batch)
# 2021-04-06 15:08:34: step 69200/50000, loss = 0.003133 (0.021 sec/batch)
# Evaluating on dev set...
# step 69200: train_loss = 0.006754
# Preds: [('NOUN', '<UNK>')]
# 2021-04-06 15:08:34: step 69220/50000, loss = 0.006405 (0.024 sec/batch)
# 2021-04-06 15:08:35: step 69240/50000, loss = 0.006642 (0.019 sec/batch)
# 2021-04-06 15:08:36: step 69260/50000, loss = 0.005420 (0.020 sec/batch)
# 2021-04-06 15:08:36: step 69280/50000, loss = 0.003782 (0.024 sec/batch)
# 2021-04-06 15:08:37: step 69300/50000, loss = 0.005922 (0.022 sec/batch)
# Evaluating on dev set...
# step 69300: train_loss = 0.007293
# Preds: [('ADV', 'However'), ('PUNCT', ','), ('PRON', 'it'), ('AUX', 'is'), ('ADJ', 'okay'), ('PART', 'to'), ('VERB', 'wash'), ('ADV', 'just'), ('DET', 'a'), ('ADJ', 'few'), ('NOUN', 'items'), ('ADP', 'with'), ('PRON', 'them'), ('PUNCT', ','), ('ADP', 'like'), ('ADJ', 'blue'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:08:38: step 69320/50000, loss = 0.007989 (0.021 sec/batch)
# 2021-04-06 15:08:38: step 69340/50000, loss = 0.011882 (0.021 sec/batch)
# 2021-04-06 15:08:39: step 69360/50000, loss = 0.003527 (0.019 sec/batch)
# 2021-04-06 15:08:39: step 69380/50000, loss = 0.015086 (0.025 sec/batch)
# 2021-04-06 15:08:40: step 69400/50000, loss = 0.002921 (0.021 sec/batch)
# Evaluating on dev set...
# step 69400: train_loss = 0.006695
# Preds: [('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('NOUN', '<UNK>')]
# 2021-04-06 15:08:41: step 69420/50000, loss = 0.005614 (0.028 sec/batch)
# 2021-04-06 15:08:41: step 69440/50000, loss = 0.004381 (0.018 sec/batch)
# 2021-04-06 15:08:42: step 69460/50000, loss = 0.006863 (0.021 sec/batch)
# 2021-04-06 15:08:42: step 69480/50000, loss = 0.005305 (0.026 sec/batch)
# 2021-04-06 15:08:43: step 69500/50000, loss = 0.004819 (0.023 sec/batch)
# Evaluating on dev set...
# step 69500: train_loss = 0.005991
# Preds: [('ADJ', 'First'), ('PROPN', '<UNK>'), ('NUM', '9'), ('PUNCT', ':'), ('NUM', '25'), ('PUNCT', '?')]
# 2021-04-06 15:08:44: step 69520/50000, loss = 0.004901 (0.022 sec/batch)
# 2021-04-06 15:08:45: step 69540/50000, loss = 0.006495 (0.018 sec/batch)
# 2021-04-06 15:08:45: step 69560/50000, loss = 0.017452 (0.022 sec/batch)
# 2021-04-06 15:08:46: step 69580/50000, loss = 0.007697 (0.021 sec/batch)
# 2021-04-06 15:08:46: step 69600/50000, loss = 0.010127 (0.021 sec/batch)
# Evaluating on dev set...
# step 69600: train_loss = 0.006592
# Preds: [('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('AUX', 'can'), ('VERB', 'lead'), ('ADP', 'to'), ('ADJ', 'serious'), ('NOUN', 'health'), ('NOUN', 'problems'), ('VERB', 'including'), ('NOUN', 'brain'), ('NOUN', 'damage'), ('PUNCT', ','), ('ADJ', '<UNK>'), ('NOUN', 'growth'), ('CCONJ', 'and'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:08:47: step 69620/50000, loss = 0.007625 (0.023 sec/batch)
# 2021-04-06 15:08:48: step 69640/50000, loss = 0.002102 (0.018 sec/batch)
# 2021-04-06 15:08:48: step 69660/50000, loss = 0.020830 (0.019 sec/batch)
# 2021-04-06 15:08:49: step 69680/50000, loss = 0.001630 (0.027 sec/batch)
# 2021-04-06 15:08:49: step 69700/50000, loss = 0.000241 (0.020 sec/batch)
# Evaluating on dev set...
# step 69700: train_loss = 0.006168
# Preds: [('DET', 'The'), ('NOUN', 'history'), ('ADP', 'of'), ('NOUN', 'values'), ('AUX', 'is'), ('ADJ', 'okay'), ('SCONJ', 'because'), ('NOUN', '<UNK>'), ('AUX', 'is'), ('ADJ', '<UNK>'), ('PUNCT', ';'), ('PRON', 'it'), ('AUX', 'does'), ('PART', 'n’t'), ('VERB', 'grow'), ('ADJ', 'old'), ('PUNCT', ','), ('ADP', 'like'), ('NOUN', 'material'), ('PUNCT', '.')]
# 2021-04-06 15:08:50: step 69720/50000, loss = 0.009594 (0.029 sec/batch)
# 2021-04-06 15:08:51: step 69740/50000, loss = 0.004873 (0.022 sec/batch)
# 2021-04-06 15:08:51: step 69760/50000, loss = 0.010955 (0.021 sec/batch)
# 2021-04-06 15:08:52: step 69780/50000, loss = 0.009768 (0.021 sec/batch)
# 2021-04-06 15:08:53: step 69800/50000, loss = 0.005710 (0.022 sec/batch)
# Evaluating on dev set...
# step 69800: train_loss = 0.007433
# Preds: [('PRON', 'This'), ('AUX', 'was'), ('DET', 'the'), ('ADJ', 'great'), ('NOUN', 'beginning'), ('ADP', 'of'), ('DET', 'a'), ('ADJ', 'new'), ('ADJ', 'social'), ('NOUN', 'revolution'), ('PUNCT', ','), ('PRON', 'which'), ('AUX', 'was'), ('DET', 'the'), ('NOUN', 'result'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'under'), ('PROPN', '<UNK>'), ('PUNCT', '('), ('X', '<UNK>'), ('X', '<UNK>'), ('PUNCT', ')'), ('PUNCT', '.')]
# 2021-04-06 15:08:54: step 69820/50000, loss = 0.003202 (0.026 sec/batch)
# 2021-04-06 15:08:54: step 69840/50000, loss = 0.008945 (0.026 sec/batch)
# 2021-04-06 15:08:55: step 69860/50000, loss = 0.003401 (0.019 sec/batch)
# 2021-04-06 15:08:55: step 69880/50000, loss = 0.004589 (0.020 sec/batch)
# 2021-04-06 15:08:56: step 69900/50000, loss = 0.022626 (0.020 sec/batch)
# Evaluating on dev set...
# step 69900: train_loss = 0.006753
# Preds: [('PROPN', '<UNK>'), ('PUNCT', ','), ('ADV', 'reportedly'), ('VERB', 'built'), ('ADP', 'for'), ('NOUN', '<UNK>'), ('NOUN', 'purposes'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'king'), ('PART', "'s"), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:08:57: step 69920/50000, loss = 0.003061 (0.021 sec/batch)
# 2021-04-06 15:08:57: step 69940/50000, loss = 0.000796 (0.018 sec/batch)
# 2021-04-06 15:08:58: step 69960/50000, loss = 0.003101 (0.027 sec/batch)
# 2021-04-06 15:08:58: step 69980/50000, loss = 0.017495 (0.021 sec/batch)
# 2021-04-06 15:08:59: step 70000/50000, loss = 0.000536 (0.018 sec/batch)
# Evaluating on dev set...
# step 70000: train_loss = 0.006926
# Preds: [('PUNCT', '"'), ('NUM', 'One'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'reasons'), ('SCONJ', 'that'), ('NOUN', '<UNK>'), ('AUX', 'is'), ('VERB', 'going'), ('ADV', 'down'), ('VERB', 'is'), ('SCONJ', 'because'), ('NOUN', 'people'), ('AUX', 'are'), ('VERB', 'taking'), ('SCONJ', 'that'), ('ADJ', 'good'), ('ADJ', 'healthy'), ('VERB', 'eating'), ('NOUN', 'message'), ('CCONJ', 'and'), ('PART', 'not'), ('VERB', 'adding'), ('NOUN', 'salt'), ('ADP', 'during'), ('NOUN', 'cooking'), ('PUNCT', '.'), ('PUNCT', '"')]
# 2021-04-06 15:09:00: step 70020/50000, loss = 0.001052 (0.019 sec/batch)
# 2021-04-06 15:09:00: step 70040/50000, loss = 0.003044 (0.020 sec/batch)
# 2021-04-06 15:09:01: step 70060/50000, loss = 0.009777 (0.019 sec/batch)
# 2021-04-06 15:09:02: step 70080/50000, loss = 0.008832 (0.017 sec/batch)
# 2021-04-06 15:09:02: step 70100/50000, loss = 0.004880 (0.028 sec/batch)
# Evaluating on dev set...
# step 70100: train_loss = 0.006945
# Preds: [('ADP', 'During'), ('DET', 'the'), ('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADV', '<UNK>'), ('VERB', 'experienced'), ('DET', 'a'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('CCONJ', 'but'), ('VERB', '<UNK>'), ('ADP', 'under'), ('ADJ', '<UNK>'), ('NOUN', 'rule'), ('PUNCT', '.')]
# 2021-04-06 15:09:03: step 70120/50000, loss = 0.006771 (0.019 sec/batch)
# 2021-04-06 15:09:04: step 70140/50000, loss = 0.003129 (0.024 sec/batch)
# 2021-04-06 15:09:04: step 70160/50000, loss = 0.003663 (0.021 sec/batch)
# 2021-04-06 15:09:05: step 70180/50000, loss = 0.001507 (0.021 sec/batch)
# 2021-04-06 15:09:05: step 70200/50000, loss = 0.002267 (0.024 sec/batch)
# Evaluating on dev set...
# step 70200: train_loss = 0.006520
# Preds: [('ADP', 'With'), ('DET', 'these'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('PRON', 'we'), ('VERB', 'hope'), ('PART', 'to'), ('VERB', 'initiate'), ('DET', 'a'), ('NOUN', 'stream'), ('ADP', 'of'), ('ADJ', '<UNK>'), ('NOUN', 'activities'), ('ADP', 'in'), ('NOUN', '<UNK>'), ('NOUN', 'universities'), ('PUNCT', ','), ('VERB', 'making'), ('NOUN', 'access'), ('PART', 'to'), ('VERB', 'support'), ('ADJ', 'easier'), ('ADP', 'for'), ('ADJ', 'new'), ('ADJ', 'digital'), ('NOUN', 'scholars'), ('PUNCT', '.')]
# 2021-04-06 15:09:06: step 70220/50000, loss = 0.002003 (0.017 sec/batch)
# 2021-04-06 15:09:07: step 70240/50000, loss = 0.013827 (0.020 sec/batch)
# 2021-04-06 15:09:07: step 70260/50000, loss = 0.008391 (0.023 sec/batch)
# 2021-04-06 15:09:08: step 70280/50000, loss = 0.003930 (0.024 sec/batch)
# 2021-04-06 15:09:08: step 70300/50000, loss = 0.013206 (0.023 sec/batch)
# Evaluating on dev set...
# step 70300: train_loss = 0.006252
# Preds: [('DET', 'Another'), ('NOUN', 'approach'), ('AUX', 'is'), ('PART', 'to'), ('VERB', 'buy'), ('NUM', 'five'), ('NOUN', 'bottles'), ('ADP', 'of'), ('NOUN', 'vodka'), ('CCONJ', 'and'), ('NUM', 'five'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:09: step 70320/50000, loss = 0.004659 (0.021 sec/batch)
# 2021-04-06 15:09:10: step 70340/50000, loss = 0.005905 (0.020 sec/batch)
# 2021-04-06 15:09:10: step 70360/50000, loss = 0.005766 (0.024 sec/batch)
# 2021-04-06 15:09:11: step 70380/50000, loss = 0.005318 (0.020 sec/batch)
# 2021-04-06 15:09:12: step 70400/50000, loss = 0.006432 (0.024 sec/batch)
# Evaluating on dev set...
# step 70400: train_loss = 0.006036
# Preds: [('PRON', 'We'), ('AUX', 'were'), ('VERB', 'coming'), ('ADP', 'with'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADV', 'like'), ('PUNCT', ','), ('VERB', 'left'), ('CCONJ', 'and'), ('ADV', 'right'), ('PUNCT', ','), ('PRON', 'we'), ('AUX', 'were'), ('VERB', 'coming'), ('ADP', 'up'), ('ADP', 'with'), ('NOUN', 'things'), ('ADP', 'like'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADP', 'in'), ('ADJ', 'high'), ('NOUN', 'school'), ('PRON', 'she'), ('VERB', 'came'), ('ADP', 'up'), ('ADP', 'with'), ('DET', 'that'), ('NUM', 'one'), ('PUNCT', ','), ('PRON', 'I'), ('VERB', 'came'), ('ADP', 'up'), ('ADP', 'with'), ('DET', 'an'), ('ADJ', 'individual'), ('NOUN', 'story'), ('VERB', 'called'), ('PROPN', '<UNK>'), ('PART', "'s"), ('PROPN', 'World'), ('PROPN', '<UNK>'), ('CCONJ', 'and'), ('PUNCT', ','), ('PRON', 'she'), ('VERB', 'wanted'), ('PART', 'to'), ('VERB', '<UNK>'), ('PRON', 'it'), ('PUNCT', ','), ('CCONJ', 'and'), ('ADV', 'so'), ('PUNCT', ','), ('PRON', 'that'), ('AUX', "'s"), ('DET', 'the'), ('NOUN', 'way'), ('PRON', 'we'), ('VERB', 'ended'), ('SCONJ', 'up'), ('VERB', 'doing'), ('PRON', 'it'), ('PUNCT', '.')]
# 2021-04-06 15:09:12: step 70420/50000, loss = 0.011214 (0.029 sec/batch)
# 2021-04-06 15:09:13: step 70440/50000, loss = 0.001498 (0.026 sec/batch)
# 2021-04-06 15:09:14: step 70460/50000, loss = 0.023781 (0.021 sec/batch)
# 2021-04-06 15:09:14: step 70480/50000, loss = 0.013004 (0.027 sec/batch)
# 2021-04-06 15:09:15: step 70500/50000, loss = 0.005983 (0.018 sec/batch)
# Evaluating on dev set...
# step 70500: train_loss = 0.006494
# Preds: [('VERB', 'Enjoy'), ('PRON', 'your'), ('ADJ', 'tasty'), ('NOUN', 'creation'), ('PUNCT', '.')]
# 2021-04-06 15:09:16: step 70520/50000, loss = 0.005284 (0.022 sec/batch)
# 2021-04-06 15:09:16: step 70540/50000, loss = 0.010100 (0.018 sec/batch)
# 2021-04-06 15:09:17: step 70560/50000, loss = 0.016183 (0.026 sec/batch)
# 2021-04-06 15:09:17: step 70580/50000, loss = 0.008382 (0.017 sec/batch)
# 2021-04-06 15:09:18: step 70600/50000, loss = 0.001817 (0.021 sec/batch)
# Evaluating on dev set...
# step 70600: train_loss = 0.006344
# Preds: [('ADP', 'Over'), ('DET', 'the'), ('NOUN', 'course'), ('ADP', 'of'), ('DET', 'the'), ('ADJ', 'next'), ('NUM', '15'), ('NOUN', 'years'), ('PUNCT', ','), ('NOUN', 'money'), ('AUX', 'was'), ('VERB', 'poured'), ('ADP', 'into'), ('ADJ', 'new'), ('NOUN', 'transportation'), ('NOUN', 'infrastructure'), ('NOUN', 'projects'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', 'restoration'), ('ADP', 'of'), ('VERB', 'surviving'), ('NOUN', '<UNK>'), ('NOUN', 'buildings'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'city'), ('PART', "'s"), ('ADJ', 'historical'), ('NOUN', 'center'), ('CCONJ', 'and'), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('ADJ', 'many'), ('ADJ', 'former'), ('ADJ', 'industrial'), ('NOUN', 'areas'), ('CCONJ', 'and'), ('DET', 'the'), ('NOUN', 'city'), ('PART', "'s"), ('NOUN', 'coastline'), ('PUNCT', '.')]
# 2021-04-06 15:09:19: step 70620/50000, loss = 0.006842 (0.018 sec/batch)
# 2021-04-06 15:09:19: step 70640/50000, loss = 0.004613 (0.019 sec/batch)
# 2021-04-06 15:09:20: step 70660/50000, loss = 0.003134 (0.020 sec/batch)
# 2021-04-06 15:09:20: step 70680/50000, loss = 0.004551 (0.022 sec/batch)
# 2021-04-06 15:09:21: step 70700/50000, loss = 0.002247 (0.023 sec/batch)
# Evaluating on dev set...
# step 70700: train_loss = 0.006236
# Preds: [('PROPN', '<UNK>'), ('PROPN', 'International'), ('PROPN', 'Airport'), ('CCONJ', 'or'), ('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PUNCT', '('), ('PROPN', 'IATA'), ('PUNCT', ':'), ('PROPN', '<UNK>'), ('PUNCT', ')'), ('AUX', 'was'), ('DET', 'a'), ('ADJ', 'military'), ('NOUN', 'air'), ('NOUN', 'base'), ('ADP', 'before'), ('DET', 'the'), ('NOUN', 'revolution'), ('PUNCT', '.')]
# 2021-04-06 15:09:22: step 70720/50000, loss = 0.001507 (0.019 sec/batch)
# 2021-04-06 15:09:22: step 70740/50000, loss = 0.009645 (0.027 sec/batch)
# 2021-04-06 15:09:23: step 70760/50000, loss = 0.003038 (0.019 sec/batch)
# 2021-04-06 15:09:24: step 70780/50000, loss = 0.001849 (0.017 sec/batch)
# 2021-04-06 15:09:24: step 70800/50000, loss = 0.011322 (0.020 sec/batch)
# Evaluating on dev set...
# step 70800: train_loss = 0.006171
# Preds: [('PRON', 'This'), ('AUX', 'will'), ('VERB', 'make'), ('DET', 'a'), ('ADJ', 'familiar'), ('NOUN', 'joke'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:25: step 70820/50000, loss = 0.002647 (0.019 sec/batch)
# 2021-04-06 15:09:26: step 70840/50000, loss = 0.007466 (0.021 sec/batch)
# 2021-04-06 15:09:26: step 70860/50000, loss = 0.001627 (0.022 sec/batch)
# 2021-04-06 15:09:27: step 70880/50000, loss = 0.002888 (0.020 sec/batch)
# 2021-04-06 15:09:27: step 70900/50000, loss = 0.001798 (0.023 sec/batch)
# Evaluating on dev set...
# step 70900: train_loss = 0.006584
# Preds: [('VERB', '<UNK>'), ('ADP', 'with'), ('DET', 'the'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:28: step 70920/50000, loss = 0.006127 (0.028 sec/batch)
# 2021-04-06 15:09:29: step 70940/50000, loss = 0.008202 (0.023 sec/batch)
# 2021-04-06 15:09:29: step 70960/50000, loss = 0.026713 (0.020 sec/batch)
# 2021-04-06 15:09:30: step 70980/50000, loss = 0.017821 (0.023 sec/batch)
# 2021-04-06 15:09:30: step 71000/50000, loss = 0.010270 (0.023 sec/batch)
# Evaluating on dev set...
# step 71000: train_loss = 0.006037
# Preds: [('NOUN', 'Labor'), ('VERB', '<UNK>'), ('ADP', 'from'), ('NOUN', '<UNK>'), ('ADP', 'to'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:31: step 71020/50000, loss = 0.001803 (0.023 sec/batch)
# 2021-04-06 15:09:32: step 71040/50000, loss = 0.004063 (0.021 sec/batch)
# 2021-04-06 15:09:32: step 71060/50000, loss = 0.000717 (0.021 sec/batch)
# 2021-04-06 15:09:33: step 71080/50000, loss = 0.010372 (0.023 sec/batch)
# 2021-04-06 15:09:34: step 71100/50000, loss = 0.004955 (0.018 sec/batch)
# Evaluating on dev set...
# step 71100: train_loss = 0.006130
# Preds: [('PRON', 'What'), ('AUX', '’s'), ('ADJ', 'funny'), ('ADP', 'to'), ('DET', 'a'), ('NOUN', 'group'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('ADJ', 'old'), ('NOUN', 'college'), ('NOUN', 'students'), ('AUX', 'may'), ('AUX', 'be'), ('ADV', 'very'), ('ADJ', 'different'), ('ADP', 'from'), ('PRON', 'what'), ('VERB', 'makes'), ('PRON', 'your'), ('NOUN', '<UNK>'), ('ADJ', 'old'), ('PUNCT', '-'), ('PROPN', 'uncle'), ('VERB', 'laugh'), ('PUNCT', '('), ('ADV', 'then'), ('ADV', 'again'), ('PUNCT', ','), ('ADV', 'maybe'), ('PART', 'not'), ('PUNCT', ')'), ('PUNCT', '.')]
# 2021-04-06 15:09:35: step 71120/50000, loss = 0.006707 (0.029 sec/batch)
# 2021-04-06 15:09:35: step 71140/50000, loss = 0.005007 (0.028 sec/batch)
# 2021-04-06 15:09:36: step 71160/50000, loss = 0.002531 (0.024 sec/batch)
# 2021-04-06 15:09:36: step 71180/50000, loss = 0.006790 (0.019 sec/batch)
# 2021-04-06 15:09:37: step 71200/50000, loss = 0.006475 (0.028 sec/batch)
# Evaluating on dev set...
# step 71200: train_loss = 0.006152
# Preds: [('ADP', 'At'), ('DET', 'the'), ('ADJ', 'initial'), ('NOUN', 'meeting'), ('PRON', 'it'), ('VERB', 'became'), ('ADJ', 'apparent'), ('SCONJ', 'that'), ('ADJ', 'most'), ('NOUN', 'participants'), ('AUX', 'were'), ('ADV', 'there'), ('PART', 'to'), ('VERB', 'learn'), ('ADV', 'more'), ('ADP', 'about'), ('ADJ', 'digital'), ('NOUN', 'humanities'), ('CCONJ', 'and'), ('AUX', 'were'), ('PART', 'not'), ('PUNCT', '('), ('ADV', 'yet'), ('PUNCT', ')'), ('ADP', 'in'), ('DET', 'the'), ('NOUN', 'situation'), ('SCONJ', 'where'), ('PRON', 'they'), ('AUX', 'were'), ('ADJ', 'able'), ('PART', 'to'), ('VERB', 'offer'), ('NOUN', 'expertise'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'subject'), ('PUNCT', '.')]
# 2021-04-06 15:09:38: step 71220/50000, loss = 0.002886 (0.021 sec/batch)
# 2021-04-06 15:09:38: step 71240/50000, loss = 0.007291 (0.024 sec/batch)
# 2021-04-06 15:09:39: step 71260/50000, loss = 0.002428 (0.018 sec/batch)
# 2021-04-06 15:09:39: step 71280/50000, loss = 0.011327 (0.017 sec/batch)
# 2021-04-06 15:09:40: step 71300/50000, loss = 0.006889 (0.027 sec/batch)
# Evaluating on dev set...
# step 71300: train_loss = 0.005837
# Preds: [('PRON', 'We'), ('AUX', 'were'), ('VERB', 'coming'), ('ADP', 'with'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADV', 'like'), ('PUNCT', ','), ('PROPN', 'left'), ('CCONJ', 'and'), ('ADV', 'right'), ('PUNCT', ','), ('PRON', 'we'), ('AUX', 'were'), ('VERB', 'coming'), ('ADP', 'up'), ('ADP', 'with'), ('NOUN', 'things'), ('ADP', 'like'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADP', 'in'), ('ADJ', 'high'), ('NOUN', 'school'), ('PRON', 'she'), ('VERB', 'came'), ('ADP', 'up'), ('ADP', 'with'), ('DET', 'that'), ('NUM', 'one'), ('PUNCT', ','), ('PRON', 'I'), ('VERB', 'came'), ('ADP', 'up'), ('ADP', 'with'), ('DET', 'an'), ('ADJ', 'individual'), ('NOUN', 'story'), ('VERB', 'called'), ('PROPN', '<UNK>'), ('PART', "'s"), ('PROPN', 'World'), ('NOUN', '<UNK>'), ('CCONJ', 'and'), ('PUNCT', ','), ('PRON', 'she'), ('VERB', 'wanted'), ('PART', 'to'), ('VERB', '<UNK>'), ('PRON', 'it'), ('PUNCT', ','), ('CCONJ', 'and'), ('ADV', 'so'), ('PUNCT', ','), ('PRON', 'that'), ('AUX', "'s"), ('DET', 'the'), ('NOUN', 'way'), ('PRON', 'we'), ('VERB', 'ended'), ('SCONJ', 'up'), ('VERB', 'doing'), ('PRON', 'it'), ('PUNCT', '.')]
# 2021-04-06 15:09:41: step 71320/50000, loss = 0.012805 (0.028 sec/batch)
# 2021-04-06 15:09:41: step 71340/50000, loss = 0.002128 (0.023 sec/batch)
# 2021-04-06 15:09:42: step 71360/50000, loss = 0.004116 (0.019 sec/batch)
# 2021-04-06 15:09:43: step 71380/50000, loss = 0.016631 (0.027 sec/batch)
# 2021-04-06 15:09:43: step 71400/50000, loss = 0.003471 (0.024 sec/batch)
# Evaluating on dev set...
# step 71400: train_loss = 0.006042
# Preds: [('PRON', 'My'), ('NOUN', 'father'), ('PART', '’s'), ('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('VERB', 'appeared'), ('PUNCT', ','), ('PRON', 'his'), ('ADJ', 'still'), ('PUNCT', ','), ('ADJ', '<UNK>'), ('NOUN', 'figure'), ('PUNCT', ','), ('CCONJ', 'and'), ('ADP', 'beside'), ('PRON', 'him'), ('DET', 'another'), ('NOUN', 'man'), ('PUNCT', ','), ('ADJ', 'tall'), ('CCONJ', 'and'), ('ADJ', '<UNK>'), ('PUNCT', ','), ('VERB', '<UNK>'), ('DET', 'an'), ('NOUN', 'island'), ('VERB', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:44: step 71420/50000, loss = 0.008943 (0.020 sec/batch)
# 2021-04-06 15:09:45: step 71440/50000, loss = 0.007561 (0.027 sec/batch)
# 2021-04-06 15:09:45: step 71460/50000, loss = 0.010779 (0.020 sec/batch)
# 2021-04-06 15:09:46: step 71480/50000, loss = 0.007283 (0.025 sec/batch)
# 2021-04-06 15:09:46: step 71500/50000, loss = 0.020626 (0.023 sec/batch)
# Evaluating on dev set...
# step 71500: train_loss = 0.006112
# Preds: [('PRON', 'They'), ('AUX', 'are'), ('ADV', 'simply'), ('ADJ', 'afraid'), ('CCONJ', 'and'), ('VERB', 'hate'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:47: step 71520/50000, loss = 0.006413 (0.020 sec/batch)
# 2021-04-06 15:09:48: step 71540/50000, loss = 0.009643 (0.019 sec/batch)
# 2021-04-06 15:09:48: step 71560/50000, loss = 0.011422 (0.018 sec/batch)
# 2021-04-06 15:09:49: step 71580/50000, loss = 0.017546 (0.021 sec/batch)
# 2021-04-06 15:09:49: step 71600/50000, loss = 0.020135 (0.020 sec/batch)
# Evaluating on dev set...
# step 71600: train_loss = 0.006986
# Preds: [('PROPN', '<UNK>'), ('CCONJ', 'and'), ('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('AUX', 'are'), ('CCONJ', 'both'), ('ADJ', '<UNK>'), ('NOUN', 'locations'), ('PUNCT', ','), ('CCONJ', 'and'), ('ADJ', 'good'), ('ADP', 'for'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('CCONJ', 'and'), ('DET', 'the'), ('NOUN', 'island'), ('AUX', 'is'), ('DET', 'the'), ('ADJ', 'ancestral'), ('NOUN', 'domain'), ('ADP', 'of'), ('DET', 'an'), ('ADJ', 'indigenous'), ('NOUN', '<UNK>'), ('PRON', 'who'), ('AUX', 'are'), ('VERB', 'managing'), ('DET', 'the'), ('NOUN', 'island'), ('ADP', 'in'), ('DET', 'a'), ('ADJ', 'sustainable'), ('NOUN', 'way'), ('CCONJ', 'and'), ('VERB', 'keeping'), ('NOUN', '<UNK>'), ('ADP', 'at'), ('DET', 'a'), ('NOUN', 'distance'), ('CCONJ', 'and'), ('NOUN', '<UNK>'), ('ADP', 'at'), ('NOUN', 'night'), ('PUNCT', '.')]
# 2021-04-06 15:09:50: step 71620/50000, loss = 0.023711 (0.022 sec/batch)
# 2021-04-06 15:09:51: step 71640/50000, loss = 0.008056 (0.025 sec/batch)
# 2021-04-06 15:09:52: step 71660/50000, loss = 0.012827 (0.022 sec/batch)
# 2021-04-06 15:09:52: step 71680/50000, loss = 0.005603 (0.020 sec/batch)
# 2021-04-06 15:09:53: step 71700/50000, loss = 0.013920 (0.021 sec/batch)
# Evaluating on dev set...
# step 71700: train_loss = 0.006315
# Preds: [('SCONJ', 'When'), ('PRON', 'I'), ('AUX', 'was'), ('DET', 'a'), ('ADJ', 'little'), ('NOUN', 'girl'), ('PUNCT', ','), ('PRON', 'he'), ('VERB', 'did'), ('PRON', 'that'), ('ADV', 'often'), ('PUNCT', ','), ('CCONJ', 'and'), ('VERB', 'called'), ('PRON', 'me'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:09:54: step 71720/50000, loss = 0.006153 (0.017 sec/batch)
# 2021-04-06 15:09:54: step 71740/50000, loss = 0.004073 (0.020 sec/batch)
# 2021-04-06 15:09:55: step 71760/50000, loss = 0.004422 (0.022 sec/batch)
# 2021-04-06 15:09:55: step 71780/50000, loss = 0.007094 (0.020 sec/batch)
# 2021-04-06 15:09:56: step 71800/50000, loss = 0.020245 (0.020 sec/batch)
# Evaluating on dev set...
# step 71800: train_loss = 0.006070
# Preds: [('CCONJ', 'And'), ('PRON', 'there'), ('VERB', 'was'), ('DET', 'a'), ('ADJ', '<UNK>'), ('NOUN', 'sound'), ('PUNCT', ','), ('DET', 'a'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('SCONJ', 'like'), ('DET', 'a'), ('NOUN', 'box'), ('VERB', 'pulled'), ('ADP', 'over'), ('NOUN', 'concrete'), ('PUNCT', '.')]
# 2021-04-06 15:09:57: step 71820/50000, loss = 0.005630 (0.018 sec/batch)
# 2021-04-06 15:09:57: step 71840/50000, loss = 0.001314 (0.018 sec/batch)
# 2021-04-06 15:09:58: step 71860/50000, loss = 0.013995 (0.018 sec/batch)
# 2021-04-06 15:09:58: step 71880/50000, loss = 0.014582 (0.026 sec/batch)
# 2021-04-06 15:09:59: step 71900/50000, loss = 0.002722 (0.016 sec/batch)
# Evaluating on dev set...
# step 71900: train_loss = 0.006052
# Preds: [('CCONJ', 'But'), ('ADP', 'at'), ('DET', 'the'), ('ADJ', 'other'), ('NOUN', 'end'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'scale'), ('PRON', 'we'), ('AUX', "'ve"), ('VERB', 'got'), ('PART', 'to'), ('VERB', 'make'), ('ADJ', 'sure'), ('DET', 'the'), ('NOUN', 'people'), ('PRON', 'who'), ('VERB', 'eat'), ('DET', 'a'), ('NOUN', 'lot'), ('ADP', 'of'), ('NOUN', 'food'), ('PUNCT', '-'), ('PRON', 'we'), ('ADV', 'all'), ('VERB', 'know'), ('DET', 'the'), ('ADJ', 'teenage'), ('NOUN', 'boy'), ('PRON', 'who'), ('VERB', 'comes'), ('NOUN', 'home'), ('ADP', 'from'), ('NOUN', 'school'), ('CCONJ', 'and'), ('VERB', 'eats'), ('DET', 'a'), ('ADJ', 'whole'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('PUNCT', '-'), ('SCONJ', 'that'), ('DET', 'those'), ('NOUN', 'people'), ('AUX', 'do'), ('PART', "n't"), ('VERB', 'get'), ('ADV', 'too'), ('ADV', 'much'), ('CCONJ', 'and'), ('VERB', 'get'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('PUNCT', '"'), ('INTJ', '<UNK>'), ('X', '<UNK>'), ('VERB', 'said'), ('PUNCT', '.')]
# 2021-04-06 15:10:00: step 71920/50000, loss = 0.009460 (0.020 sec/batch)
# 2021-04-06 15:10:00: step 71940/50000, loss = 0.005048 (0.022 sec/batch)
# 2021-04-06 15:10:01: step 71960/50000, loss = 0.005170 (0.018 sec/batch)
# 2021-04-06 15:10:01: step 71980/50000, loss = 0.014759 (0.018 sec/batch)
# 2021-04-06 15:10:02: step 72000/50000, loss = 0.021926 (0.024 sec/batch)
# Evaluating on dev set...
# step 72000: train_loss = 0.006222
# Preds: [('PRON', 'There'), ('AUX', 'should'), ('PART', "n't"), ('AUX', 'be'), ('NOUN', 'anyone'), ('VERB', 'suffering'), ('ADP', 'from'), ('ADJ', '<UNK>'), ('NOUN', '<UNK>'), ('ADP', 'in'), ('DET', 'a'), ('ADJ', 'developed'), ('NOUN', 'country'), ('ADP', 'like'), ('PROPN', 'Australia'), ('PUNCT', '.'), ('PUNCT', '"')]
# 2021-04-06 15:10:03: step 72020/50000, loss = 0.002898 (0.023 sec/batch)
# 2021-04-06 15:10:03: step 72040/50000, loss = 0.001878 (0.026 sec/batch)
# 2021-04-06 15:10:04: step 72060/50000, loss = 0.008036 (0.027 sec/batch)
# 2021-04-06 15:10:05: step 72080/50000, loss = 0.002350 (0.027 sec/batch)
# 2021-04-06 15:10:05: step 72100/50000, loss = 0.012070 (0.019 sec/batch)
# Evaluating on dev set...
# step 72100: train_loss = 0.006432
# Preds: [('DET', 'Every'), ('NOUN', 'joke'), ('VERB', 'has'), ('DET', 'a'), ('PUNCT', '“'), ('NOUN', 'target'), ('PUNCT', ','), ('PUNCT', '”'), ('PRON', 'which'), ('AUX', 'is'), ('PRON', 'what'), ('DET', 'the'), ('NOUN', 'joke'), ('VERB', 'is'), ('ADV', 'about'), ('PUNCT', '.')]
# 2021-04-06 15:10:06: step 72120/50000, loss = 0.014036 (0.026 sec/batch)
# 2021-04-06 15:10:07: step 72140/50000, loss = 0.000439 (0.020 sec/batch)
# 2021-04-06 15:10:07: step 72160/50000, loss = 0.000958 (0.018 sec/batch)
# 2021-04-06 15:10:08: step 72180/50000, loss = 0.004212 (0.020 sec/batch)
# 2021-04-06 15:10:08: step 72200/50000, loss = 0.004401 (0.021 sec/batch)
# Evaluating on dev set...
# step 72200: train_loss = 0.007490
# Preds: [('SCONJ', 'If'), ('PRON', 'your'), ('NOUN', 'washing'), ('NOUN', 'machine'), ('AUX', 'is'), ('ADJ', 'worth'), ('PRON', 'its'), ('NOUN', 'salt'), ('PUNCT', ','), ('PRON', 'it'), ('AUX', 'will'), ('VERB', '<UNK>'), ('DET', 'those'), ('NOUN', '<UNK>'), ('ADP', 'in'), ('DET', 'a'), ('NOUN', '<UNK>'), ('CCONJ', 'and'), ('VERB', 'tie'), ('PRON', 'them'), ('ADP', 'in'), ('DET', 'a'), ('NOUN', '<UNK>'), ('NOUN', '<UNK>'), ('SCONJ', 'unless'), ('PRON', 'you'), ('VERB', 'prevent'), ('PRON', 'it'), ('PUNCT', '.')]
# 2021-04-06 15:10:09: step 72220/50000, loss = 0.004511 (0.026 sec/batch)
# 2021-04-06 15:10:10: step 72240/50000, loss = 0.003102 (0.022 sec/batch)
# 2021-04-06 15:10:10: step 72260/50000, loss = 0.004387 (0.024 sec/batch)
# 2021-04-06 15:10:11: step 72280/50000, loss = 0.004911 (0.022 sec/batch)
# 2021-04-06 15:10:11: step 72300/50000, loss = 0.013332 (0.025 sec/batch)
# Evaluating on dev set...
# step 72300: train_loss = 0.006347
# Preds: [('ADP', 'In'), ('NUM', '2015'), ('PUNCT', ','), ('DET', 'an'), ('NOUN', '<UNK>'), ('AUX', 'was'), ('VERB', 'started'), ('PART', 'to'), ('VERB', 'set'), ('ADP', 'up'), ('DET', 'a'), ('NOUN', '<UNK>'), ('VERB', 'speaking'), ('ADJ', '<UNK>'), ('NOUN', 'community'), ('ADP', 'in'), ('DET', 'the'), ('PROPN', 'Netherlands'), ('CCONJ', 'and'), ('PROPN', 'Belgium'), ('PUNCT', ','), ('VERB', 'based'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'example'), ('ADP', 'of'), ('DET', 'the'), ('ADJ', 'American'), ('ADJ', '<UNK>'), ('NOUN', 'space'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('NOUN', '<UNK>'), ('PUNCT', ','), ('VERB', '<UNK>'), ('NOUN', 'graduate'), ('NOUN', 'students'), ('PUNCT', ','), ('CCONJ', 'and'), ('NOUN', 'information'), ('NOUN', '<UNK>'), ('PART', 'to'), ('VERB', 'discuss'), ('NOUN', 'topics'), ('PUNCT', '‘'), ('SCONJ', 'Where'), ('DET', 'the'), ('ADJ', 'Digital'), ('NOUN', 'Humanities'), ('CCONJ', 'and'), ('NOUN', '<UNK>'), ('VERB', 'meet'), ('PUNCT', '’'), ('PUNCT', '.')]
# 2021-04-06 15:10:12: step 72320/50000, loss = 0.003078 (0.023 sec/batch)
# 2021-04-06 15:10:13: step 72340/50000, loss = 0.005787 (0.027 sec/batch)
# 2021-04-06 15:10:14: step 72360/50000, loss = 0.001303 (0.020 sec/batch)
# 2021-04-06 15:10:14: step 72380/50000, loss = 0.015781 (0.021 sec/batch)
# 2021-04-06 15:10:15: step 72400/50000, loss = 0.006144 (0.027 sec/batch)
# Evaluating on dev set...
# step 72400: train_loss = 0.006623
# Preds: [('PRON', 'Our'), ('NOUN', 'plan'), ('AUX', 'is'), ('PART', 'to'), ('VERB', '<UNK>'), ('DET', 'a'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('NUM', '6'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('DET', 'each'), ('NUM', 'one'), ('ADJ', 'full'), ('NOUN', 'day'), ('PUNCT', '.')]
# 2021-04-06 15:10:16: step 72420/50000, loss = 0.009829 (0.021 sec/batch)
# 2021-04-06 15:10:16: step 72440/50000, loss = 0.005238 (0.022 sec/batch)
# 2021-04-06 15:10:17: step 72460/50000, loss = 0.009253 (0.018 sec/batch)
# 2021-04-06 15:10:17: step 72480/50000, loss = 0.005132 (0.017 sec/batch)
# 2021-04-06 15:10:18: step 72500/50000, loss = 0.000709 (0.019 sec/batch)
# Evaluating on dev set...
# step 72500: train_loss = 0.006501
# Preds: [('NOUN', 'Steps')]
# 2021-04-06 15:10:19: step 72520/50000, loss = 0.010688 (0.025 sec/batch)
# 2021-04-06 15:10:19: step 72540/50000, loss = 0.006404 (0.022 sec/batch)
# 2021-04-06 15:10:20: step 72560/50000, loss = 0.003830 (0.029 sec/batch)
# 2021-04-06 15:10:20: step 72580/50000, loss = 0.012162 (0.024 sec/batch)
# 2021-04-06 15:10:21: step 72600/50000, loss = 0.005195 (0.027 sec/batch)
# Evaluating on dev set...
# step 72600: train_loss = 0.006371
# Preds: [('NOUN', 'Today'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', '<UNK>'), ('VERB', 'remain'), ('DET', 'the'), ('ADJ', 'dominant'), ('SCONJ', 'if'), ('PART', 'not'), ('ADJ', 'entire'), ('NOUN', 'population'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:10:22: step 72620/50000, loss = 0.010799 (0.019 sec/batch)
# 2021-04-06 15:10:22: step 72640/50000, loss = 0.004740 (0.027 sec/batch)
# 2021-04-06 15:10:23: step 72660/50000, loss = 0.007060 (0.023 sec/batch)
# 2021-04-06 15:10:24: step 72680/50000, loss = 0.007207 (0.023 sec/batch)
# 2021-04-06 15:10:24: step 72700/50000, loss = 0.006073 (0.023 sec/batch)
# Evaluating on dev set...
# step 72700: train_loss = 0.006819
# Preds: [('VERB', 'Look'), ('PUNCT', ','), ('DET', 'the'), ('ADJ', 'new'), ('NOUN', 'age'), ('AUX', 'is'), ('ADJ', 'unprecedented'), ('PUNCT', '.')]
# 2021-04-06 15:10:25: step 72720/50000, loss = 0.004016 (0.017 sec/batch)
# 2021-04-06 15:10:26: step 72740/50000, loss = 0.001638 (0.019 sec/batch)
# 2021-04-06 15:10:26: step 72760/50000, loss = 0.006492 (0.020 sec/batch)
# 2021-04-06 15:10:27: step 72780/50000, loss = 0.002474 (0.019 sec/batch)
# 2021-04-06 15:10:27: step 72800/50000, loss = 0.005936 (0.024 sec/batch)
# Evaluating on dev set...
# step 72800: train_loss = 0.006692
# ...
# step 127200: train_loss = 0.006075
# Preds: [('DET', 'The'), ('NOUN', 'mosque'), ('AUX', 'was'), ('VERB', 'designed'), ('PART', 'to'), ('AUX', 'be'), ('DET', 'a'), ('ADJ', 'private'), ('NOUN', 'mosque'), ('ADP', 'for'), ('DET', 'the'), ('ADJ', 'royal'), ('NOUN', 'family'), ('CCONJ', 'and'), ('ADV', 'therefore'), ('PRON', 'it'), ('AUX', 'does'), ('PART', 'not'), ('VERB', 'have'), ('DET', 'any'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:39:07: step 127220/50000, loss = 0.005170 (0.020 sec/batch)
# 2021-04-06 15:39:08: step 127240/50000, loss = 0.005388 (0.026 sec/batch)
# 2021-04-06 15:39:09: step 127260/50000, loss = 0.002041 (0.020 sec/batch)
# 2021-04-06 15:39:09: step 127280/50000, loss = 0.005328 (0.024 sec/batch)
# 2021-04-06 15:39:10: step 127300/50000, loss = 0.004623 (0.025 sec/batch)
# Evaluating on dev set...
# step 127300: train_loss = 0.005508
# Preds: [('NOUN', '<UNK>'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('NOUN', '<UNK>'), ('SYM', '/'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('CCONJ', 'or'), ('DET', 'an'), ('ADV', 'extremely'), ('ADJ', 'clean'), ('NOUN', 'T-shirt')]
# 2021-04-06 15:39:11: step 127320/50000, loss = 0.005602 (0.019 sec/batch)
# 2021-04-06 15:39:11: step 127340/50000, loss = 0.004118 (0.019 sec/batch)
# 2021-04-06 15:39:12: step 127360/50000, loss = 0.001415 (0.020 sec/batch)
# 2021-04-06 15:39:12: step 127380/50000, loss = 0.011664 (0.025 sec/batch)
# 2021-04-06 15:39:13: step 127400/50000, loss = 0.006850 (0.021 sec/batch)
# Evaluating on dev set...
# step 127400: train_loss = 0.005930
# Preds: [('NOUN', 'Tips'), ('PUNCT', '.')]
# 2021-04-06 15:39:14: step 127420/50000, loss = 0.005142 (0.022 sec/batch)
# 2021-04-06 15:39:14: step 127440/50000, loss = 0.003121 (0.020 sec/batch)
# 2021-04-06 15:39:15: step 127460/50000, loss = 0.005819 (0.021 sec/batch)
# 2021-04-06 15:39:15: step 127480/50000, loss = 0.009255 (0.022 sec/batch)
# 2021-04-06 15:39:16: step 127500/50000, loss = 0.007222 (0.021 sec/batch)
# Evaluating on dev set...
# step 127500: train_loss = 0.005930
# Preds: [('DET', 'The'), ('ADJ', 'ancient'), ('PROPN', 'Olympic'), ('PROPN', 'Games'), ('VERB', 'took'), ('NOUN', 'place'), ('SCONJ', 'in'), ('PROPN', '<UNK>'), ('ADP', 'from'), ('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('ADP', 'to'), ('PROPN', '<UNK>'), ('X', 'AD'), ('PUNCT', '.')]
# 2021-04-06 15:39:17: step 127520/50000, loss = 0.006054 (0.021 sec/batch)
# 2021-04-06 15:39:17: step 127540/50000, loss = 0.009975 (0.023 sec/batch)
# 2021-04-06 15:39:18: step 127560/50000, loss = 0.004555 (0.023 sec/batch)
# 2021-04-06 15:39:19: step 127580/50000, loss = 0.008794 (0.018 sec/batch)
# 2021-04-06 15:39:19: step 127600/50000, loss = 0.013821 (0.018 sec/batch)
# Evaluating on dev set...
# step 127600: train_loss = 0.005700
# Preds: [('VERB', 'Wash'), ('ADV', 'alone'), ('CCONJ', 'or'), ('ADP', 'with'), ('PUNCT', '"'), ('ADP', 'like'), ('PUNCT', '"'), ('NOUN', 'clothing'), ('PUNCT', '.')]
# 2021-04-06 15:39:20: step 127620/50000, loss = 0.006458 (0.023 sec/batch)
# 2021-04-06 15:39:21: step 127640/50000, loss = 0.007148 (0.026 sec/batch)
# 2021-04-06 15:39:21: step 127660/50000, loss = 0.003139 (0.021 sec/batch)
# 2021-04-06 15:39:22: step 127680/50000, loss = 0.003068 (0.017 sec/batch)
# 2021-04-06 15:39:22: step 127700/50000, loss = 0.001914 (0.021 sec/batch)
# Evaluating on dev set...
# step 127700: train_loss = 0.005998
# Preds: [('VERB', 'Shake'), ('ADV', 'occasionally'), ('SCONJ', 'so'), ('DET', 'the'), ('NOUN', '<UNK>'), ('VERB', '<UNK>'), ('ADV', 'well'), ('PUNCT', '.')]
# 2021-04-06 15:39:23: step 127720/50000, loss = 0.005848 (0.022 sec/batch)
# 2021-04-06 15:39:24: step 127740/50000, loss = 0.006784 (0.022 sec/batch)
# 2021-04-06 15:39:24: step 127760/50000, loss = 0.003463 (0.027 sec/batch)
# 2021-04-06 15:39:25: step 127780/50000, loss = 0.006041 (0.027 sec/batch)
# 2021-04-06 15:39:25: step 127800/50000, loss = 0.002387 (0.026 sec/batch)
# Evaluating on dev set...
# step 127800: train_loss = 0.005950
# Preds: [('ADP', 'In'), ('NUM', '<UNK>'), ('SCONJ', 'that'), ('PROPN', '<UNK>'), ('AUX', 'was'), ('VERB', '<UNK>'), ('ADP', 'as'), ('DET', 'a'), ('NOUN', 'town'), ('CCONJ', 'and'), ('DET', 'the'), ('NOUN', 'name'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'town'), ('AUX', 'was'), ('ADV', '<UNK>'), ('VERB', 'changed'), ('ADP', 'from'), ('PROPN', '<UNK>'), ('X', 'de'), ('X', '<UNK>'), ('ADP', 'to'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:39:26: step 127820/50000, loss = 0.001031 (0.025 sec/batch)
# 2021-04-06 15:39:27: step 127840/50000, loss = 0.007242 (0.021 sec/batch)
# 2021-04-06 15:39:27: step 127860/50000, loss = 0.010795 (0.020 sec/batch)
# 2021-04-06 15:39:28: step 127880/50000, loss = 0.006335 (0.017 sec/batch)
# 2021-04-06 15:39:29: step 127900/50000, loss = 0.007157 (0.022 sec/batch)
# Evaluating on dev set...
# step 127900: train_loss = 0.006631
# Preds: [('PRON', 'He'), ('AUX', 'was'), ('ADP', 'in'), ('ADJ', 'many'), ('NOUN', 'ways'), ('DET', 'a'), ('NOUN', 'world'), ('ADP', 'in'), ('PRON', 'himself'), ('PUNCT', ','), ('ADJ', 'whole'), ('ADP', 'as'), ('DET', 'a'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:39:30: step 127920/50000, loss = 0.007277 (0.023 sec/batch)
# 2021-04-06 15:39:30: step 127940/50000, loss = 0.000647 (0.022 sec/batch)
# 2021-04-06 15:39:31: step 127960/50000, loss = 0.008188 (0.020 sec/batch)
# 2021-04-06 15:39:31: step 127980/50000, loss = 0.001483 (0.029 sec/batch)
# 2021-04-06 15:39:32: step 128000/50000, loss = 0.003093 (0.028 sec/batch)
# Evaluating on dev set...
# step 128000: train_loss = 0.005432
# Preds: [('PRON', 'My'), ('NOUN', 'father'), ('VERB', 'took'), ('ADP', 'off'), ('PRON', 'his'), ('NOUN', 'coat'), ('CCONJ', 'and'), ('VERB', '<UNK>'), ('PRON', 'it'), ('ADP', 'over'), ('DET', 'the'), ('NOUN', 'edge'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', '<UNK>'), ('CCONJ', 'and'), ('SCONJ', 'when'), ('PRON', 'I'), ('VERB', 'came'), ('ADV', 'back'), ('ADP', 'from'), ('NOUN', '<UNK>'), ('PRON', 'I'), ('VERB', '<UNK>'), ('PRON', 'his'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:39:33: step 128020/50000, loss = 0.003387 (0.026 sec/batch)
# 2021-04-06 15:39:33: step 128040/50000, loss = 0.001541 (0.018 sec/batch)
# 2021-04-06 15:39:34: step 128060/50000, loss = 0.008748 (0.022 sec/batch)
# 2021-04-06 15:39:34: step 128080/50000, loss = 0.002234 (0.018 sec/batch)
# 2021-04-06 15:39:35: step 128100/50000, loss = 0.004092 (0.020 sec/batch)
# Evaluating on dev set...
# step 128100: train_loss = 0.005752
# Preds: [('ADV', '<UNK>'), ('PUNCT', ','), ('ADV', '<UNK>'), ('PUNCT', ','), ('PRON', 'we'), ('AUX', 'do'), ('ADV', '<UNK>'), ('VERB', '<UNK>'), ('CCONJ', 'and'), ('ADJ', '<UNK>'), ('X', '<UNK>'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PRON', 'our'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('ADV', 'immediately'), ('ADP', 'upon'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PRON', 'this'), ('PUNCT', ','), ('PRON', 'our'), ('NOUN', '<UNK>'), ('PUNCT', ','), ('PART', 'to'), ('VERB', 'proceed'), ('ADP', 'with'), ('DET', 'a'), ('ADJ', '<UNK>'), ('NOUN', 'force'), ('CCONJ', 'and'), ('ADJ', 'clear'), ('DET', 'the'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('PROPN', 'Congress'), ('PUNCT', '.')]
# 2021-04-06 15:39:36: step 128120/50000, loss = 0.007757 (0.021 sec/batch)
# 2021-04-06 15:39:36: step 128140/50000, loss = 0.007001 (0.020 sec/batch)
# 2021-04-06 15:39:37: step 128160/50000, loss = 0.036476 (0.021 sec/batch)
# 2021-04-06 15:39:38: step 128180/50000, loss = 0.008642 (0.023 sec/batch)
# 2021-04-06 15:39:38: step 128200/50000, loss = 0.006898 (0.028 sec/batch)
# Evaluating on dev set...
# step 128200: train_loss = 0.005718
# Preds: [('PRON', 'We'), ('VERB', 'walked'), ('ADV', 'back'), ('ADP', 'through'), ('DET', 'the'), ('NOUN', 'school'), ('SCONJ', 'because'), ('PRON', 'it'), ('AUX', 'was'), ('VERB', '<UNK>'), ('PUNCT', ','), ('PRON', 'my'), ('NOUN', 'father'), ('ADJ', 'tall'), ('ADP', 'in'), ('PRON', 'his'), ('NOUN', 'navy'), ('NOUN', 'suit'), ('CCONJ', 'and'), ('PRON', 'my'), ('NOUN', 'shoes'), ('VERB', 'going'), ('VERB', '<UNK>'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:39:39: step 128220/50000, loss = 0.000385 (0.025 sec/batch)
# 2021-04-06 15:39:40: step 128240/50000, loss = 0.006857 (0.018 sec/batch)
# 2021-04-06 15:39:40: step 128260/50000, loss = 0.001112 (0.022 sec/batch)
# 2021-04-06 15:39:41: step 128280/50000, loss = 0.011906 (0.020 sec/batch)
# 2021-04-06 15:39:41: step 128300/50000, loss = 0.008295 (0.020 sec/batch)
# Evaluating on dev set...
# step 128300: train_loss = 0.006304
# Preds: [('NOUN', '<UNK>'), ('AUX', 'has'), ('VERB', 'taken'), ('DET', 'an'), ('ADJ', 'important'), ('NOUN', 'position'), ('ADP', 'in'), ('DET', 'the'), ('NOUN', 'tourism'), ('NOUN', 'industry'), ('PUNCT', '.')]
# 2021-04-06 15:39:42: step 128320/50000, loss = 0.025082 (0.026 sec/batch)
# 2021-04-06 15:39:43: step 128340/50000, loss = 0.002822 (0.021 sec/batch)
# 2021-04-06 15:39:43: step 128360/50000, loss = 0.002968 (0.019 sec/batch)
# 2021-04-06 15:39:44: step 128380/50000, loss = 0.004529 (0.022 sec/batch)
# 2021-04-06 15:39:44: step 128400/50000, loss = 0.005157 (0.018 sec/batch)
# Evaluating on dev set...
# step 128400: train_loss = 0.005761
# Preds: [('DET', 'The'), ('NOUN', 'space'), ('ADP', 'under'), ('DET', 'the'), ('NOUN', '<UNK>'), ('AUX', 'was'), ('ADJ', 'secret'), ('CCONJ', 'and'), ('ADJ', 'dark'), ('PUNCT', '.')]
# 2021-04-06 15:39:45: step 128420/50000, loss = 0.003769 (0.017 sec/batch)
# 2021-04-06 15:39:46: step 128440/50000, loss = 0.001646 (0.023 sec/batch)
# 2021-04-06 15:39:46: step 128460/50000, loss = 0.010895 (0.020 sec/batch)
# 2021-04-06 15:39:47: step 128480/50000, loss = 0.012117 (0.027 sec/batch)
# 2021-04-06 15:39:48: step 128500/50000, loss = 0.014469 (0.019 sec/batch)
# Evaluating on dev set...
# step 128500: train_loss = 0.006205
# Preds: [('NUM', 'One'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('PART', "'s"), ('NOUN', '<UNK>'), ('PROPN', '<UNK>')]
# 2021-04-06 15:39:49: step 128520/50000, loss = 0.009961 (0.018 sec/batch)
# 2021-04-06 15:39:49: step 128540/50000, loss = 0.005130 (0.022 sec/batch)
# 2021-04-06 15:39:50: step 128560/50000, loss = 0.002305 (0.020 sec/batch)
# 2021-04-06 15:39:50: step 128580/50000, loss = 0.009498 (0.019 sec/batch)
# 2021-04-06 15:39:51: step 128600/50000, loss = 0.010610 (0.026 sec/batch)
# Evaluating on dev set...
# step 128600: train_loss = 0.005594
# Preds: [('SCONJ', 'If'), ('PRON', 'you'), ('AUX', 'did'), ('PART', 'n’t'), ('VERB', 'know'), ('ADV', 'already'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', '<UNK>'), ('AUX', 'is'), ('DET', 'the'), ('ADJ', 'top'), ('ADJ', 'front'), ('NOUN', 'part'), ('ADP', 'with'), ('DET', 'the'), ('NOUN', 'breast'), ('NOUN', 'pockets'), ('PUNCT', '.')]
# 2021-04-06 15:39:52: step 128620/50000, loss = 0.002729 (0.021 sec/batch)
# 2021-04-06 15:39:52: step 128640/50000, loss = 0.001344 (0.027 sec/batch)
# 2021-04-06 15:39:53: step 128660/50000, loss = 0.002036 (0.022 sec/batch)
# 2021-04-06 15:39:53: step 128680/50000, loss = 0.012001 (0.027 sec/batch)
# 2021-04-06 15:39:54: step 128700/50000, loss = 0.004424 (0.020 sec/batch)
# Evaluating on dev set...
# step 128700: train_loss = 0.006654
# Preds: [('ADJ', '<UNK>'), ('ADJ', 'Olympic'), ('PROPN', 'Games')]
# 2021-04-06 15:39:55: step 128720/50000, loss = 0.000841 (0.021 sec/batch)
# 2021-04-06 15:39:55: step 128740/50000, loss = 0.000564 (0.021 sec/batch)
# 2021-04-06 15:39:56: step 128760/50000, loss = 0.002989 (0.025 sec/batch)
# 2021-04-06 15:39:57: step 128780/50000, loss = 0.004287 (0.026 sec/batch)
# 2021-04-06 15:39:57: step 128800/50000, loss = 0.016410 (0.021 sec/batch)
# Evaluating on dev set...
# step 128800: train_loss = 0.006340
# Preds: [('CCONJ', 'and'), ('NOUN', 'jokes'), ('VERB', '<UNK>'), ('ADJ', '<UNK>'), ('NOUN', 'knowledge'), ('PUNCT', '('), ('ADP', 'of'), ('PUNCT', ','), ('ADP', 'for'), ('NOUN', 'example'), ('PUNCT', ','), ('NOUN', 'science'), ('CCONJ', 'or'), ('ADJ', 'old'), ('NOUN', 'movies'), ('PUNCT', ')'), ('AUX', 'will'), ('ADV', 'only'), ('AUX', 'be'), ('VERB', 'appreciated'), ('ADP', 'by'), ('NOUN', 'people'), ('PRON', 'who'), ('VERB', '<UNK>'), ('DET', 'that'), ('NOUN', 'knowledge'), ('PUNCT', '.')]
# 2021-04-06 15:39:58: step 128820/50000, loss = 0.001630 (0.019 sec/batch)
# 2021-04-06 15:39:59: step 128840/50000, loss = 0.003868 (0.018 sec/batch)
# 2021-04-06 15:39:59: step 128860/50000, loss = 0.002671 (0.019 sec/batch)
# 2021-04-06 15:40:00: step 128880/50000, loss = 0.001008 (0.019 sec/batch)
# 2021-04-06 15:40:00: step 128900/50000, loss = 0.007327 (0.021 sec/batch)
# Evaluating on dev set...
# step 128900: train_loss = 0.006252
# Preds: [('PRON', 'It'), ('AUX', 'is'), ('DET', 'a'), ('ADJ', '<UNK>'), ('NOUN', 'day'), ('NOUN', 'trip'), ('ADP', 'from'), ('NOUN', '<UNK>'), ('PART', 'to'), ('VERB', 'visit'), ('NUM', '<UNK>'), ('PUNCT', ','), ('CCONJ', 'but'), ('ADV', 'quite'), ('ADJ', 'interesting'), ('PUNCT', '.')]
# 2021-04-06 15:40:01: step 128920/50000, loss = 0.006521 (0.023 sec/batch)
# 2021-04-06 15:40:02: step 128940/50000, loss = 0.016447 (0.024 sec/batch)
# 2021-04-06 15:40:02: step 128960/50000, loss = 0.007278 (0.024 sec/batch)
# 2021-04-06 15:40:03: step 128980/50000, loss = 0.001736 (0.019 sec/batch)
# 2021-04-06 15:40:03: step 129000/50000, loss = 0.009345 (0.024 sec/batch)
# Evaluating on dev set...
# step 129000: train_loss = 0.006370
# Preds: [('VERB', 'Think'), ('ADJ', 'similar'), ('NOUN', 'clothing'), ('PUNCT', ','), ('ADV', '<UNK>'), ('DET', 'the'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:40:04: step 129020/50000, loss = 0.012580 (0.019 sec/batch)
# 2021-04-06 15:40:05: step 129040/50000, loss = 0.009323 (0.018 sec/batch)
# 2021-04-06 15:40:05: step 129060/50000, loss = 0.002066 (0.022 sec/batch)
# 2021-04-06 15:40:06: step 129080/50000, loss = 0.006552 (0.022 sec/batch)
# 2021-04-06 15:40:07: step 129100/50000, loss = 0.003029 (0.023 sec/batch)
# Evaluating on dev set...
# step 129100: train_loss = 0.005998
# Preds: [('PROPN', '<UNK>'), ('PROPN', '<UNK>'), ('PROPN', 'Mosque'), ('PUNCT', ','), ('NOUN', 'interior'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', '<UNK>')]
# 2021-04-06 15:40:07: step 129120/50000, loss = 0.003117 (0.019 sec/batch)
# 2021-04-06 15:40:08: step 129140/50000, loss = 0.001401 (0.018 sec/batch)
# 2021-04-06 15:40:09: step 129160/50000, loss = 0.009271 (0.028 sec/batch)
# 2021-04-06 15:40:09: step 129180/50000, loss = 0.005378 (0.024 sec/batch)
# 2021-04-06 15:40:10: step 129200/50000, loss = 0.007467 (0.020 sec/batch)
# Evaluating on dev set...
# step 129200: train_loss = 0.005218
# Preds: [('ADV', 'How'), ('AUX', 'do'), ('PRON', 'you'), ('VERB', 'come'), ('ADP', 'to'), ('DET', 'an'), ('NOUN', 'understanding'), ('PART', 'to'), ('VERB', 'make'), ('NOUN', 'peace'), ('ADJ', 'possible'), ('PUNCT', '?')]
# 2021-04-06 15:40:11: step 129220/50000, loss = 0.009752 (0.020 sec/batch)
# 2021-04-06 15:40:11: step 129240/50000, loss = 0.007742 (0.027 sec/batch)
# 2021-04-06 15:40:12: step 129260/50000, loss = 0.008149 (0.023 sec/batch)
# 2021-04-06 15:40:12: step 129280/50000, loss = 0.001732 (0.026 sec/batch)
# 2021-04-06 15:40:13: step 129300/50000, loss = 0.002875 (0.021 sec/batch)
# Evaluating on dev set...
# step 129300: train_loss = 0.005577
# Preds: [('DET', 'Another'), ('NOUN', 'approach'), ('AUX', 'is'), ('PART', 'to'), ('VERB', 'buy'), ('NUM', 'five'), ('NOUN', 'bottles'), ('ADP', 'of'), ('NOUN', 'vodka'), ('CCONJ', 'and'), ('NUM', 'five'), ('NOUN', '<UNK>'), ('ADP', 'of'), ('NOUN', '<UNK>'), ('PUNCT', '.')]
# 2021-04-06 15:40:14: step 129320/50000, loss = 0.001710 (0.024 sec/batch)
# 2021-04-06 15:40:14: step 129340/50000, loss = 0.010779 (0.021 sec/batch)
# 2021-04-06 15:40:15: step 129360/50000, loss = 0.012117 (0.021 sec/batch)
# 2021-04-06 15:40:15: step 129380/50000, loss = 0.008469 (0.027 sec/batch)
# 2021-04-06 15:40:16: step 129400/50000, loss = 0.008543 (0.021 sec/batch)
# Evaluating on dev set...
# step 129400: train_loss = 0.006117
# Preds: [('ADV', 'Once'), ('DET', 'the'), ('ADJ', 'first'), ('NOUN', '<UNK>'), ('AUX', 'has'), ('AUX', 'been'), ('VERB', '<UNK>'), ('PUNCT', ','), ('VERB', 'wash'), ('ADP', 'out'), ('DET', 'the'), ('NOUN', '<UNK>'), ('CCONJ', 'and'), ('VERB', 'pour'), ('DET', 'the'), ('ADJ', '<UNK>'), ('NOUN', 'vodka'), ('ADV', 'back'), ('ADP', 'in'), ('PUNCT', '.')]
